# %%
import os
import torch
import librosa
import librosa.display
import scipy
import glob
import random
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
from collections import defaultdict
from sklearn.preprocessing import StandardScaler
import math
import copy
import time

# %% [markdown]
# ## Constants

# %%
fs = 16e3 # [Hz] sampling frequency
windowLength = 256 # {from paper}
fftLength = windowLength
overlap = round(0.25 * windowLength) # overlap of 75% makes good prediction; {from paper}
window = scipy.signal.hamming(windowLength, sym=False) # Hamming window {from paper}
numSegments = 8
numFeatures = fftLength // 2 + 1

# %% [markdown]
# ## Utilities

# %%
def read_audio(filepath, sample_rate, normalize=True):
    """Read an audio file and return it as a numpy array"""
    audio, sr = librosa.load(filepath, sr=sample_rate)
    #Normalization?
    if normalize:
        div_fac = 1 / np.max(np.abs(audio)) / 3.0
        audio = audio * div_fac
    return audio, sr
    
def remove_silent_frames(audio, filename):
    
    array_sum = np.sum(audio)
    array_has_nan = np.isnan(array_sum)
    
    if array_has_nan:
        print("NNNNNNNNNNNNNNNNNAAAAAAAAAAAAAAAAAAAAAAAAAAAANNNNNNNNNNNNNNNNNNNNNNNN", filename)
    
    trimed_audio = []
    indices = librosa.effects.split(audio, hop_length = overlap, top_db=20)

    for index in indices:
        trimed_audio.extend(audio[index[0]: index[1]])
    return np.array(trimed_audio)

def add_noise_to_clean_audio(clean_audio, noise_signal):
    """Adds noise to an audio sample"""
    if len(clean_audio) >= len(noise_signal):
        # print("The noisy signal is smaller than the clean audio input. Duplicating the noise.")
        while len(clean_audio) >= len(noise_signal):
            noise_signal = np.append(noise_signal, noise_signal)

    # Extract a noise segment from a random location in the noise file
    ind = np.random.randint(0, noise_signal.size - clean_audio.size)
    
    noise_segment = noise_signal[ind: ind + clean_audio.size]

    speech_power = np.sum(clean_audio ** 2)
    noise_power = np.sum(noise_segment ** 2)
    noisy_audio = clean_audio + np.sqrt(speech_power / noise_power / 16) * noise_segment
    return noisy_audio

def _phase_aware_scaling(clean_spectral_magnitude, clean_phase, noise_phase):
    assert clean_phase.shape == noise_phase.shape, "Shapes must match."
    return clean_spectral_magnitude * np.cos(clean_phase - noise_phase)


def _audio_random_crop(audio, duration):
    audio_duration_secs = librosa.core.get_duration(audio, fs)

    ## duration: length of the cropped audio in seconds
    if duration >= audio_duration_secs:
        print(f"Passed duration {duration} greater than audio duration of { audio_duration_secs}")
        return audio

    audio_duration_ms = math.floor(audio_duration_secs * fs)
    duration_ms = math.floor(duration * fs)
    idx = np.random.randint(0, audio_duration_ms - duration_ms)
    return audio[idx: idx + duration_ms]

def extend_all_speaches_to_same_size(sample_speach_filenames):
    speaches = []
    
    max_length = 0
    for filename in sample_speach_filenames:
        sound_audio, sampl_rate_sound = read_audio(filename, sample_rate=fs)
        if max_length < len(sound_audio):
            max_length = len(sound_audio)
        speaches.append([sound_audio, sampl_rate_sound])
        
    for sound_data in speaches:
        sound_data[0] = np.pad(sound_data[0], (0, max_length - len(sound_data[0])), mode='constant')
        
    return speaches
        
def play_sound(audio, sample_rate):
    ipd.display(ipd.Audio(data=audio, rate=sample_rate))

# %%
def prepare_input_features(stft_features, numSegments, numFeatures):
    noisySTFT = np.concatenate([stft_features[:, 0:numSegments - 1], stft_features], axis=1)
    stftSegments = np.zeros((numFeatures, numSegments, noisySTFT.shape[1] - numSegments + 1))

    for index in range(noisySTFT.shape[1] - numSegments + 1):
        stftSegments[:, :, index] = noisySTFT[:, index:index + numSegments]
    return stftSegments

# %% [markdown]
# ## Dataset

# %%
path_to_noise_dataset = "../../dataset/noise_dataset/audio/"
#all_noise_filenames = glob.glob(os.path.join(path_to_noise_dataset, 'fold3', '*.*'))
#print(all_noise_filenames[0:10])
all_noise_filenames = ["../../dataset/noise_dataset/audio/fold3/18594-1-1-0.wav"]

path_to_speach_dataset = "../../dataset/en/clips"
all_speach_filenames = glob.glob(os.path.join(path_to_speach_dataset, '*.*'))
#print(all_speach_filenames[0:10])
#print(len(all_speach_filenames))

# %% [markdown]
# ## Sound

# %%
speach_sample_size = 500 # dataset has ~1e7 sounds, so we need smaller samplegg
sample_speach_filenames = random.sample(all_speach_filenames, speach_sample_size)

print(len(sample_speach_filenames))

train_set_percentage = 70 #%
validation_set_percentage = 20 #%
test_set_percentage = 10 #%

speach_filenames_train, speach_filenames_validation, speach_filenames_test = \
    np.split(sample_speach_filenames, \
             [int(speach_sample_size * train_set_percentage / 100.), \
              int(speach_sample_size * (train_set_percentage + validation_set_percentage) / 100.)])

print(len(speach_filenames_train))
print(len(speach_filenames_validation))
print(len(speach_filenames_test))
# Out:
# 500
# 350
# 100
# 50

# %%
def fetch_data_for_nn(sample_speach_filenames):
    speach_data_for_nn = []
    noised_data_for_nn = []
    cnt = 0
    for filename in sample_speach_filenames:
         
        if cnt % 5 == 0:
            print(f"Completed: {cnt * 100 / len(sample_speach_filenames):.3f} %")
        cnt += 1
            
        sound_audio, sampl_rate_sound = read_audio(filename, sample_rate=fs)
        #play sound_audio without cutting empty voice
        #play_sound(sound_audio, sampl_rate_sound)

        sound_audio = remove_silent_frames(sound_audio, filename)

        sound_audio = _audio_random_crop(sound_audio, duration = 0.4)
        
        speach_stft = librosa.stft(sound_audio, n_fft=fftLength, win_length=windowLength, hop_length=overlap, window=window, center=True)
        speach_stft_abs = np.abs(speach_stft)
        speach_stft_phase = np.angle(speach_stft)

        #speach_stft_abs_db = librosa.amplitude_to_db(speach_stft_abs,ref=np.max)
        #fig, ax = plt.subplots()
        #img = librosa.display.specshow(speach_stft_abs_db, y_axis='linear', x_axis='time', ax=ax)
        #ax.set_title('Clear speach')
        #fig.colorbar(img, ax=ax, format="%+2.0f dB")

        random_noise_signal_index = 0 #np.random.randint(0, len(all_noise_filenames) - 1)
        #print(all_noise_filenames[random_noise_signal_index])
        noise_audio, sampl_rate_noise = read_audio(all_noise_filenames[random_noise_signal_index], sample_rate=fs)

        noise_audio = remove_silent_frames(noise_audio, filename)

        noise_stft = librosa.stft(noise_audio, n_fft=fftLength, win_length=windowLength, hop_length=overlap, window=window, center=True)
        noise_stft_abs = np.abs(noise_stft)
        noise_stft_phase = np.angle(noise_stft)

        #noise_stft_abs_db = librosa.amplitude_to_db(noise_stft_abs,ref=np.max)
    
        noise_and_speach = add_noise_to_clean_audio(sound_audio, noise_audio)    

        noise_and_speach_stft = librosa.stft(noise_and_speach, n_fft=fftLength, win_length=windowLength, hop_length=overlap, window=window, center=True)
        noise_and_speach_stft_abs = np.abs(noise_and_speach_stft)
        noise_and_speach_stft_phase = np.angle(noise_and_speach_stft)

        speach_stft_abs = _phase_aware_scaling(speach_stft_abs, speach_stft_phase, noise_and_speach_stft_phase)
        
        #scaler = StandardScaler(copy=False, with_mean=True, with_std=True)
        #noise_and_speach_stft_abs = scaler.fit_transform(noise_and_speach_stft_abs)
        #speach_stft_abs = scaler.transform(speach_stft_abs)

        #if cnt % 5 == 0:
            
            #play_sound(sound_audio, fs)
            #play_sound(noise_and_speach, fs)

        
        noise_and_speach_chunks = prepare_input_features(noise_and_speach_stft_abs, numSegments, numFeatures)

        #print(noise_and_speach_chunks.shape, speach_stft_abs.shape)

        noise_and_speach_chunks = np.transpose(noise_and_speach_chunks, (2, 0, 1))
        speach_stft_abs = np.transpose(speach_stft_abs, (1, 0))
    #    noise_stft_phase = np.transpose(noise_stft_phase, (1, 0))

        #print(noise_and_speach_chunks.shape, speach_stft_abs.shape)

        speach_data_for_nn.append(speach_stft_abs)
        noised_data_for_nn.append(noise_and_speach_chunks)

        #play sound_audio
        #play_sound(sound_audio, sampl_rate_sound)
        #play noise_audio
        #play_sound(noise_audio, sampl_rate_noise)
        #play noise_and_speach
        #play_sound(noise_and_speach, sampl_rate_sound)

        #print(noise_and_speach_stft_abs.shape)
        #print("--")

    #print("++")
    speach_data_for_nn = np.concatenate(speach_data_for_nn)
    speach_data_for_nn = speach_data_for_nn[:,:,None]
    noised_data_for_nn = np.concatenate(noised_data_for_nn)
    
    return noised_data_for_nn, speach_data_for_nn

# %%
# train data fetch
train_noised_data_for_nn, train_speach_data_for_nn = fetch_data_for_nn(speach_filenames_train)
train_noised_data_for_nn = train_noised_data_for_nn.astype(np.float32)
train_speach_data_for_nn = train_speach_data_for_nn.astype(np.float32)


print(train_noised_data_for_nn.shape, train_speach_data_for_nn.shape)

# validation data fetch
validation_noised_data_for_nn, validation_speach_data_for_nn = fetch_data_for_nn(speach_filenames_validation)
validation_noised_data_for_nn = validation_noised_data_for_nn.astype(np.float32)
validation_speach_data_for_nn = validation_speach_data_for_nn.astype(np.float32)

print(validation_noised_data_for_nn.shape, validation_speach_data_for_nn.shape)

# test data fetch
test_noised_data_for_nn, test_speach_data_for_nn = fetch_data_for_nn(speach_filenames_test)
test_noised_data_for_nn = test_noised_data_for_nn.astype(np.float32)
test_speach_data_for_nn = test_speach_data_for_nn.astype(np.float32)

print(test_noised_data_for_nn.shape, test_speach_data_for_nn.shape)
# Out:
# Completed: 0.000 %
# Completed: 1.429 %
# Completed: 2.857 %
# Completed: 4.286 %
# Completed: 5.714 %
# Completed: 7.143 %
# Completed: 8.571 %
# Completed: 10.000 %
# Passed duration 0.4 greater than audio duration of 0.3
# Completed: 11.429 %
# Completed: 12.857 %
# Completed: 14.286 %
# Completed: 15.714 %
# Completed: 17.143 %
# Completed: 18.571 %
# Completed: 20.000 %
# Completed: 21.429 %
# Completed: 22.857 %
# Completed: 24.286 %
# Completed: 25.714 %
# Passed duration 0.4 greater than audio duration of 0.392
# Completed: 27.143 %
# Completed: 28.571 %
# Completed: 30.000 %
# Completed: 31.429 %
# Completed: 32.857 %
# Completed: 34.286 %
# Completed: 35.714 %
# Completed: 37.143 %
# Completed: 38.571 %
# Completed: 40.000 %
# Completed: 41.429 %
# Completed: 42.857 %
# Completed: 44.286 %
# Completed: 45.714 %
# Completed: 47.143 %
# Completed: 48.571 %
# Completed: 50.000 %
# Completed: 51.429 %
# Completed: 52.857 %
# Completed: 54.286 %
# Completed: 55.714 %
# Completed: 57.143 %
# Completed: 58.571 %
# Completed: 60.000 %
# Completed: 61.429 %
# Completed: 62.857 %
# Completed: 64.286 %
# Completed: 65.714 %
# Completed: 67.143 %
# Completed: 68.571 %
# Completed: 70.000 %
# Completed: 71.429 %
# Completed: 72.857 %
# Completed: 74.286 %
# Passed duration 0.4 greater than audio duration of 0.14
# Completed: 75.714 %
# Completed: 77.143 %
# Completed: 78.571 %
# Completed: 80.000 %
# Completed: 81.429 %
# Completed: 82.857 %
# Completed: 84.286 %
# Completed: 85.714 %
# Completed: 87.143 %
# Completed: 88.571 %
# Completed: 90.000 %
# Completed: 91.429 %
# Completed: 92.857 %
# Completed: 94.286 %
# Completed: 95.714 %
# Passed duration 0.4 greater than audio duration of 0.384
# Completed: 97.143 %
# Completed: 98.571 %
# (35254, 129, 8) (35254, 129, 1)
# Completed: 0.000 %
# Completed: 5.000 %
# Completed: 10.000 %
# Completed: 15.000 %
# Passed duration 0.4 greater than audio duration of 0.376
# Completed: 20.000 %
# Completed: 25.000 %
# Completed: 30.000 %
# Completed: 35.000 %
# Completed: 40.000 %
# Completed: 45.000 %
# Completed: 50.000 %
# Completed: 55.000 %
# Completed: 60.000 %
# Completed: 65.000 %
# Completed: 70.000 %
# Completed: 75.000 %
# Completed: 80.000 %
# Completed: 85.000 %
# Completed: 90.000 %
# Completed: 95.000 %
# (10094, 129, 8) (10094, 129, 1)
# Completed: 0.000 %
# Completed: 10.000 %
# Completed: 20.000 %
# Completed: 30.000 %
# Completed: 40.000 %
# Completed: 50.000 %
# Completed: 60.000 %
# Completed: 70.000 %
# Completed: 80.000 %
# Completed: 90.000 %
# (5050, 129, 8) (5050, 129, 1)

# %%
print(speach_filenames_train[30])
# Out:
# ../../dataset/en/clips\common_voice_en_20733867.mp3

# %% [markdown]
# ## Dataset and Dataloader

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
batch_size = 2048

# %%
train_set=TensorDataset(torch.from_numpy(train_noised_data_for_nn), torch.from_numpy(train_speach_data_for_nn))
train_loader=DataLoader(train_set, batch_size=batch_size, shuffle=True)


validation_set=TensorDataset(torch.from_numpy(validation_noised_data_for_nn), torch.from_numpy(validation_speach_data_for_nn))
validation_loader=DataLoader(train_set, batch_size = batch_size, shuffle = True)

#data_set = {'train': train_l}

test_set=TensorDataset(torch.from_numpy(test_noised_data_for_nn), torch.from_numpy(test_speach_data_for_nn))
test_loader=DataLoader(train_set, batch_size = batch_size, shuffle = True)

# %%
for xb,yb in train_loader:

    for i in range(len(xb)):
        
        play_sound(xb[1], fs)
        play_sound(yb[1], fs)
        
        noise_and_speach_stft_abs_db = librosa.amplitude_to_db(xb[1],ref=np.max)
        fig, ax = plt.subplots()
        img = librosa.display.specshow(noise_and_speach_stft_abs_db, y_axis='linear', x_axis='time', ax=ax)
        ax.set_title('Noisy speach')
        fig.colorbar(img, ax=ax, format="%+2.0f dB")

        noise_and_speach_stft_abs_db = librosa.amplitude_to_db(yb[1],ref=np.max)
        fig, ax = plt.subplots()
        img = librosa.display.specshow(noise_and_speach_stft_abs_db, y_axis='linear', x_axis='time', ax=ax)
        ax.set_title('Clear speack')
        fig.colorbar(img, ax=ax, format="%+2.0f dB")

        break
    break

for xb,yb in validation_loader:

    for i in range(len(xb)):
        noise_and_speach_stft_abs_db = librosa.amplitude_to_db(xb[1],ref=np.max)
        fig, ax = plt.subplots()
        img = librosa.display.specshow(noise_and_speach_stft_abs_db, y_axis='linear', x_axis='time', ax=ax)
        ax.set_title('Noisy speach')
        fig.colorbar(img, ax=ax, format="%+2.0f dB")

        noise_and_speach_stft_abs_db = librosa.amplitude_to_db(yb[1],ref=np.max)
        fig, ax = plt.subplots()
        img = librosa.display.specshow(noise_and_speach_stft_abs_db, y_axis='linear', x_axis='time', ax=ax)
        ax.set_title('Clear speack')
        fig.colorbar(img, ax=ax, format="%+2.0f dB")

        break
    break

for xb,yb in test_loader:

    for i in range(len(xb)):
        noise_and_speach_stft_abs_db = librosa.amplitude_to_db(xb[1],ref=np.max)
        fig, ax = plt.subplots()
        img = librosa.display.specshow(noise_and_speach_stft_abs_db, y_axis='linear', x_axis='time', ax=ax)
        ax.set_title('Noisy speach')
        fig.colorbar(img, ax=ax, format="%+2.0f dB")

        noise_and_speach_stft_abs_db = librosa.amplitude_to_db(yb[1],ref=np.max)
        fig, ax = plt.subplots()
        img = librosa.display.specshow(noise_and_speach_stft_abs_db, y_axis='linear', x_axis='time', ax=ax)
        ax.set_title('Clear speack')
        fig.colorbar(img, ax=ax, format="%+2.0f dB")

        break
    break
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Model

# %%
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ### Hyperparameters

# %%
learning_rate = 0.0015

# %%
class Lambda(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func = func
    def forward(self, x):
        return self.func(x)

# %%
class PrintShape(nn.Module):
    def __init__(self,i):
        super().__init__()
        self.i=i
    def forward(self, x):
        print("PrintShape: stage:",self.i,"shape",x.shape)
        return x

# %%
class SaveConnection(nn.Module):
    def __init__(self,i):
        super().__init__()
        #print("lista sad init:",saved_connections)
        self.i=i
        #if i==0:
        #    saved_connections=[]
        if self.i==len(saved_connections):
            saved_connections.append(-1)
        else:
            print("dodaje se konekcija na lose mesto: i,len:",i,len(saved_connections))
    def forward(self, x):
        saved_connections[self.i]=x
        return x

# %%
class AddConnection(nn.Module):
    def __init__(self,index):
        super().__init__()
        self.index=index
    def forward(self,x):
        return saved_connections[self.index]+x

# %%
#(Conv, ReLU, BN)  15, Conv.
#(18-30-8)  5, 1 (9-5-9)  5, 129
saved_connections=[]


model = nn.Sequential(
    Lambda(lambda x: x.view(-1, 1, numFeatures, numSegments)),
    #PrintShape(0),

    nn.Conv2d(1, 18, kernel_size=(9, numSegments), padding = (4,0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(18),
    #PrintShape(10),

    nn.Conv2d(18, 30, kernel_size=(5,1), padding = (2, 0), bias = False),
    SaveConnection(0),
    nn.ReLU(),
    nn.BatchNorm2d(30),
    #PrintShape(11),

    nn.Conv2d(30, 8, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(8),
    #PrintShape(1),
    # -- 1

    nn.Conv2d(8, 18, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(18),

    nn.Conv2d(18, 30, kernel_size=(5,1), padding = (2, 0), bias = False),
    SaveConnection(1),
    nn.ReLU(),
    nn.BatchNorm2d(30),

    nn.Conv2d(30, 8, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(8),
    #PrintShape(2),
    # -- 2   
    
    nn.Conv2d(8, 18, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(18),

    nn.Conv2d(18, 30, kernel_size=(5,1), padding = (2, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(30),

    nn.Conv2d(30, 8, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(8),
    #PrintShape(3),
    # -- 3

    nn.Conv2d(8, 18, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(18),

    nn.Conv2d(18, 30, kernel_size=(5,1), padding = (2, 0), bias = False),
    AddConnection(1),
    nn.ReLU(),
    nn.BatchNorm2d(30),

    nn.Conv2d(30, 8, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(8),
    #PrintShape(4),
    # -- 4 

    nn.Conv2d(8, 18, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(18),

    nn.Conv2d(18, 30, kernel_size=(5,1), padding = (2, 0), bias = False),
    AddConnection(0),
    nn.ReLU(),
    nn.BatchNorm2d(30),

    nn.Conv2d(30, 8, kernel_size=(9,1), padding = (4, 0), bias = False),
    nn.ReLU(),
    nn.BatchNorm2d(8),
    #PrintShape(5),
    # -- 5
    
    nn.Dropout(p=0.2),
    nn.Conv2d(8, 1, kernel_size=(129,1), padding = (64,0))

)

device=torch.device("cuda")
model.to(device)

print(f"Using device {device}, (cuda:0 is prefered over CPU).")  

#optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum = 0.9)
optimizer = optim.Adam(model.parameters(), lr = learning_rate)
# Out:
# Using device cuda, (cuda:0 is prefered over CPU).

# %%
def loss_mse(a, b):
    return ((a - b) ** 2).mean()

# %%
next(model.parameters()).is_cuda
# Out:
# True

# %% [markdown]
# ## Train

# %%
for xb,yb in train_loader:
    
    xb,yb=xb.to(device),yb.to(device)

    pred = model(xb)
    print("pred, yb shape:",pred.shape,yb.shape)
    
    pred=pred.squeeze()
    yb=yb.squeeze()
    print("squeezed pred, yb shape:",pred.shape,yb.shape)
         
    loss = loss_mse(pred, yb)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    break

print("pred-yb shape:",(pred-yb).shape)
# Out:
# pred, yb shape: torch.Size([2048, 1, 129, 1]) torch.Size([2048, 129, 1])
# squeezed pred, yb shape: torch.Size([2048, 129]) torch.Size([2048, 129])
# pred-yb shape: torch.Size([2048, 129])

# %%
print(len(saved_connections))
# Out:
# 2

# %%
num_epochs = 100
best_model_weights={}

def train_model(model, optimizer, num_epochs):
    metrics = defaultdict(list)
    first_epoch=True
    best_loss=0
    best_epoch=0
    learning_rate_divider=1
    number_of_lr_dividing=0
    start_time=time.time()
    
    print("Velicina seta:",len(train_loader.dataset))

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # training
        running_loss = 0.0
        #running_corrects = 0
        
        model.train()
        
        for xb,yb in train_loader:
            
            xb,yb=xb.to(device),yb.to(device)

            pred = model(xb)
            
            #print("before:",pred.shape,yb.shape)
            #pred=pred.squeeze()
            #yb=yb.squeeze()
            #print("after:",pred.shape,yb.shape)
            
            #_, preds = torch.max(pred, 1)            
            loss = loss_mse(pred.squeeze(), yb.squeeze())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # statistics
            running_loss += loss.item() * xb.size(0)
            
            #print("shapes:",preds.shape,yb.data.shape)
            #running_corrects += torch.sum(preds == yb.data).item()

        epoch_loss = running_loss / len(train_loader.dataset)
        #epoch_acc = float(running_corrects) / len(train_loader)           

        print(f'Training Loss: {epoch_loss:.4f}')

        metrics["train" + "_loss"].append(epoch_loss)
        #metrics["train" + "_acc"].append(epoch_acc)

        
        # validation
        running_loss = 0.0
        #running_corrects = 0
        
        model.eval()

        for xb,yb in validation_loader:
            xb,yb=xb.to(device),yb.to(device)

            pred=model(xb)
            

            #_, preds = torch.max(pred, 1)            
            loss = loss_mse(pred.squeeze(), yb.squeeze())

            # statistics
            running_loss += loss.item() * xb.size(0)
            #running_corrects += torch.sum(preds == yb.data).item()
            
        epoch_loss = running_loss / len(validation_loader.dataset)
        #epoch_acc = float(running_corrects) / len(validation_loader)   
        
        if first_epoch:
            best_loss=epoch_loss
            best_epoch=0
            first_epoch=False
        elif epoch_loss<=best_loss:
            best_epoch=epoch
            best_loss=epoch_loss
            best_model_weights=copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(),"C:\\Users\\psiml\\Desktop\\model\\nedeljaDodovicAudioCrop.pth")
        else:
            print("Trenutni model nije sacuvan jer je loss veci sad")
        
        if epoch-best_epoch>0 and (epoch-best_epoch)%4==0:
            print("Learning rate se polovi!")
            for param_group in optimizer.param_groups:
                param_group['lr'] = learning_rate*learning_rate_divider/(learning_rate_divider+1)
            learning_rate_divider+=1
            number_of_lr_dividing+=1

        print(f'Validation Loss: {epoch_loss:.4f}')
        print("Learning rate divider",learning_rate_divider)
        if learning_rate_divider == 8:
            break
        
        metrics["val" + "_loss"].append(epoch_loss)
        #metrics["val" + "_acc"].append(epoch_acc)

        #print(f"Epoch {epoch}: {avg_loss:.3f}")
        
        
        # deep copy the model
        #if epoch_acc > best_acc:
        #    best_acc = epoch_acc
        #    best_model_wts = copy.deepcopy(model.state_dict())
        
        print("Vreme od pocetka simulacije:",(time.time()-start_time),"sekundi")
        
    model.load_state_dict(best_model_weights)
    print("Broj polovljenja:",number_of_lr_dividing)
    
    return model.state_dict(), metrics, best_epoch

# %%
trained_model, metrics, best_epoch = train_model(model, optimizer, num_epochs)
# Out:
# Velicina seta: 35254
# Epoch 0/99
# ----------
# Training Loss: 0.2284
# Validation Loss: 0.1195
# Learning rate divider 1
# Vreme od pocetka simulacije: 9.436111688613892 sekundi
# Epoch 1/99
# ----------
# Training Loss: 0.0778
# Validation Loss: 0.0456
# Learning rate divider 1
# Vreme od pocetka simulacije: 18.92316246032715 sekundi
# Epoch 2/99
# ----------
# Training Loss: 0.0467
# Validation Loss: 0.0251
# Learning rate divider 1
# Vreme od pocetka simulacije: 28.36549949645996 sekundi
# Epoch 3/99
# ----------
# Training Loss: 0.0333
# Validation Loss: 0.0191
# Learning rate divider 1
# Vreme od pocetka simulacije: 37.83388590812683 sekundi
# Epoch 4/99
# ----------
# Training Loss: 0.0266
# Validation Loss: 0.0141
# Learning rate divider 1
# Vreme od pocetka simulacije: 47.34447145462036 sekundi
# Epoch 5/99
# ----------
# Training Loss: 0.0225
# Validation Loss: 0.0123
# Learning rate divider 1
# Vreme od pocetka simulacije: 56.89414596557617 sekundi
# Epoch 6/99
# ----------
# Training Loss: 0.0196
# Validation Loss: 0.0094
# Learning rate divider 1
# Vreme od pocetka simulacije: 66.35298824310303 sekundi
# Epoch 7/99
# ----------
# Training Loss: 0.0181
# Validation Loss: 0.0084
# Learning rate divider 1
# Vreme od pocetka simulacije: 75.8561282157898 sekundi
# Epoch 8/99
# ----------
# Training Loss: 0.0169
# Validation Loss: 0.0076
# Learning rate divider 1
# Vreme od pocetka simulacije: 85.27290272712708 sekundi
# Epoch 9/99
# ----------
# Training Loss: 0.0159
# Validation Loss: 0.0069
# Learning rate divider 1
# Vreme od pocetka simulacije: 94.81409120559692 sekundi
# Epoch 10/99
# ----------
# Training Loss: 0.0151
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0071
# Learning rate divider 1
# Vreme od pocetka simulacije: 104.26218581199646 sekundi
# Epoch 11/99
# ----------
# Training Loss: 0.0147
# Validation Loss: 0.0061
# Learning rate divider 1
# Vreme od pocetka simulacije: 113.90616106987 sekundi
# Epoch 12/99
# ----------
# Training Loss: 0.0144
# Validation Loss: 0.0061
# Learning rate divider 1
# Vreme od pocetka simulacije: 123.23114800453186 sekundi
# Epoch 13/99
# ----------
# Training Loss: 0.0140
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0072
# Learning rate divider 1
# Vreme od pocetka simulacije: 132.85213994979858 sekundi
# Epoch 14/99
# ----------
# Training Loss: 0.0137
# Validation Loss: 0.0054
# Learning rate divider 1
# Vreme od pocetka simulacije: 142.19699096679688 sekundi
# Epoch 15/99
# ----------
# Training Loss: 0.0135
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0062
# Learning rate divider 1
# Vreme od pocetka simulacije: 151.731591463089 sekundi
# Epoch 16/99
# ----------
# Training Loss: 0.0133
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0058
# Learning rate divider 1
# Vreme od pocetka simulacije: 161.3950412273407 sekundi
# Epoch 17/99
# ----------
# Training Loss: 0.0134
# Validation Loss: 0.0054
# Learning rate divider 1
# Vreme od pocetka simulacije: 170.84116625785828 sekundi
# Epoch 18/99
# ----------
# Training Loss: 0.0128
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0067
# Learning rate divider 1
# Vreme od pocetka simulacije: 180.28551030158997 sekundi
# Epoch 19/99
# ----------
# Training Loss: 0.0129
# Validation Loss: 0.0050
# Learning rate divider 1
# Vreme od pocetka simulacije: 189.75045824050903 sekundi
# Epoch 20/99
# ----------
# Training Loss: 0.0128
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0052
# Learning rate divider 1
# Vreme od pocetka simulacije: 199.23522090911865 sekundi
# Epoch 21/99
# ----------
# Training Loss: 0.0126
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0051
# Learning rate divider 1
# Vreme od pocetka simulacije: 208.7161829471588 sekundi
# Epoch 22/99
# ----------
# Training Loss: 0.0123
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0051
# Learning rate divider 1
# Vreme od pocetka simulacije: 218.30171251296997 sekundi
# Epoch 23/99
# ----------
# Training Loss: 0.0123
# Trenutni model nije sacuvan jer je loss veci sad
# Learning rate se polovi!
# Validation Loss: 0.0053
# Learning rate divider 2
# Vreme od pocetka simulacije: 227.8315532207489 sekundi
# Epoch 24/99
# ----------
# Training Loss: 0.0120
# Validation Loss: 0.0048
# Learning rate divider 2
# Vreme od pocetka simulacije: 237.28588700294495 sekundi
# Epoch 25/99
# ----------
# Training Loss: 0.0118
# Validation Loss: 0.0046
# Learning rate divider 2
# Vreme od pocetka simulacije: 246.72367215156555 sekundi
# Epoch 26/99
# ----------
# Training Loss: 0.0119
# Validation Loss: 0.0045
# Learning rate divider 2
# Vreme od pocetka simulacije: 256.17902874946594 sekundi
# Epoch 27/99
# ----------
# Training Loss: 0.0118
# Validation Loss: 0.0043
# Learning rate divider 2
# Vreme od pocetka simulacije: 265.6660258769989 sekundi
# Epoch 28/99
# ----------
# Training Loss: 0.0117
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0057
# Learning rate divider 2
# Vreme od pocetka simulacije: 275.11786675453186 sekundi
# Epoch 29/99
# ----------
# Training Loss: 0.0118
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0050
# Learning rate divider 2
# Vreme od pocetka simulacije: 284.62137722969055 sekundi
# Epoch 30/99
# ----------
# Training Loss: 0.0117
# Validation Loss: 0.0042
# Learning rate divider 2
# Vreme od pocetka simulacije: 294.114871263504 sekundi
# Epoch 31/99
# ----------
# Training Loss: 0.0116
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0051
# Learning rate divider 2
# Vreme od pocetka simulacije: 303.5899589061737 sekundi
# Epoch 32/99
# ----------
# Training Loss: 0.0116
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0047
# Learning rate divider 2
# Vreme od pocetka simulacije: 313.0187289714813 sekundi
# Epoch 33/99
# ----------
# Training Loss: 0.0114
# Validation Loss: 0.0042
# Learning rate divider 2
# Vreme od pocetka simulacije: 322.4819836616516 sekundi
# Epoch 34/99
# ----------
# Training Loss: 0.0113
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0043
# Learning rate divider 2
# Vreme od pocetka simulacije: 332.0085015296936 sekundi
# Epoch 35/99
# ----------
# Training Loss: 0.0113
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0049
# Learning rate divider 2
# Vreme od pocetka simulacije: 341.4589731693268 sekundi
# Epoch 36/99
# ----------
# Training Loss: 0.0114
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0050
# Learning rate divider 2
# Vreme od pocetka simulacije: 350.8276779651642 sekundi
# Epoch 37/99
# ----------
# Training Loss: 0.0113
# Validation Loss: 0.0041
# Learning rate divider 2
# Vreme od pocetka simulacije: 360.32660150527954 sekundi
# Epoch 38/99
# ----------
# Training Loss: 0.0112
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0042
# Learning rate divider 2
# Vreme od pocetka simulacije: 369.7550573348999 sekundi
# Epoch 39/99
# ----------
# Training Loss: 0.0111
# Validation Loss: 0.0040
# Learning rate divider 2
# Vreme od pocetka simulacije: 379.22657084465027 sekundi
# Epoch 40/99
# ----------
# Training Loss: 0.0111
# Validation Loss: 0.0040
# Learning rate divider 2
# Vreme od pocetka simulacije: 388.7324650287628 sekundi
# Epoch 41/99
# ----------
# Training Loss: 0.0111
# Validation Loss: 0.0039
# Learning rate divider 2
# Vreme od pocetka simulacije: 398.2332615852356 sekundi
# Epoch 42/99
# ----------
# Training Loss: 0.0111
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0046
# Learning rate divider 2
# Vreme od pocetka simulacije: 407.65985107421875 sekundi
# Epoch 43/99
# ----------
# Training Loss: 0.0112
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0053
# Learning rate divider 2
# Vreme od pocetka simulacije: 417.1187541484833 sekundi
# Epoch 44/99
# ----------
# Training Loss: 0.0114
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0040
# Learning rate divider 2
# Vreme od pocetka simulacije: 426.6450242996216 sekundi
# Epoch 45/99
# ----------
# Training Loss: 0.0111
# Trenutni model nije sacuvan jer je loss veci sad
# Learning rate se polovi!
# Validation Loss: 0.0040
# Learning rate divider 3
# Vreme od pocetka simulacije: 436.130117893219 sekundi
# Epoch 46/99
# ----------
# Training Loss: 0.0110
# Validation Loss: 0.0039
# Learning rate divider 3
# Vreme od pocetka simulacije: 445.63421869277954 sekundi
# Epoch 47/99
# ----------
# Training Loss: 0.0109
# Validation Loss: 0.0039
# Learning rate divider 3
# Vreme od pocetka simulacije: 455.07656025886536 sekundi
# Epoch 48/99
# ----------
# Training Loss: 0.0109
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0068
# Learning rate divider 3
# Vreme od pocetka simulacije: 464.5769169330597 sekundi
# Epoch 49/99
# ----------
# Training Loss: 0.0115
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0042
# Learning rate divider 3
# Vreme od pocetka simulacije: 474.0981225967407 sekundi
# Epoch 50/99
# ----------
# Training Loss: 0.0115
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0043
# Learning rate divider 3
# Vreme od pocetka simulacije: 483.57651472091675 sekundi
# Epoch 51/99
# ----------
# Training Loss: 0.0111
# Trenutni model nije sacuvan jer je loss veci sad
# Learning rate se polovi!
# Validation Loss: 0.0063
# Learning rate divider 4
# Vreme od pocetka simulacije: 493.12912249565125 sekundi
# Epoch 52/99
# ----------
# Training Loss: 0.0113
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0050
# Learning rate divider 4
# Vreme od pocetka simulacije: 502.6643536090851 sekundi
# Epoch 53/99
# ----------
# Training Loss: 0.0114
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0044
# Learning rate divider 4
# Vreme od pocetka simulacije: 512.2110648155212 sekundi
# Epoch 54/99
# ----------
# Training Loss: 0.0108
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0045
# Learning rate divider 4
# Vreme od pocetka simulacije: 521.6609477996826 sekundi
# Epoch 55/99
# ----------
# Training Loss: 0.0108
# Trenutni model nije sacuvan jer je loss veci sad
# Learning rate se polovi!
# Validation Loss: 0.0042
# Learning rate divider 5
# Vreme od pocetka simulacije: 531.2002193927765 sekundi
# Epoch 56/99
# ----------
# Training Loss: 0.0107
# Validation Loss: 0.0037
# Learning rate divider 5
# Vreme od pocetka simulacije: 540.8150897026062 sekundi
# Epoch 57/99
# ----------
# Training Loss: 0.0106
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0037
# Learning rate divider 5
# Vreme od pocetka simulacije: 550.3881387710571 sekundi
# Epoch 58/99
# ----------
# Training Loss: 0.0107
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0053
# Learning rate divider 5
# Vreme od pocetka simulacije: 559.8859786987305 sekundi
# Epoch 59/99
# ----------
# Training Loss: 0.0106
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0041
# Learning rate divider 5
# Vreme od pocetka simulacije: 569.3931436538696 sekundi
# Epoch 60/99
# ----------
# Training Loss: 0.0104
# Validation Loss: 0.0037
# Learning rate divider 5
# Vreme od pocetka simulacije: 578.9143793582916 sekundi
# Epoch 61/99
# ----------
# Training Loss: 0.0106
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0039
# Learning rate divider 5
# Vreme od pocetka simulacije: 588.4458277225494 sekundi
# Epoch 62/99
# ----------
# Training Loss: 0.0106
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0070
# Learning rate divider 5
# Vreme od pocetka simulacije: 598.0762147903442 sekundi
# Epoch 63/99
# ----------
# Training Loss: 0.0108
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0044
# Learning rate divider 5
# Vreme od pocetka simulacije: 607.5374007225037 sekundi
# Epoch 64/99
# ----------
# Training Loss: 0.0111
# Trenutni model nije sacuvan jer je loss veci sad
# Learning rate se polovi!
# Validation Loss: 0.0039
# Learning rate divider 6
# Vreme od pocetka simulacije: 617.0149579048157 sekundi
# Epoch 65/99
# ----------
# Training Loss: 0.0107
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0060
# Learning rate divider 6
# Vreme od pocetka simulacije: 626.4793283939362 sekundi
# Epoch 66/99
# ----------
# Training Loss: 0.0110
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0046
# Learning rate divider 6
# Vreme od pocetka simulacije: 636.0229423046112 sekundi
# Epoch 67/99
# ----------
# Training Loss: 0.0107
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0038
# Learning rate divider 6
# Vreme od pocetka simulacije: 645.4761917591095 sekundi
# Epoch 68/99
# ----------
# Training Loss: 0.0105
# Trenutni model nije sacuvan jer je loss veci sad
# Learning rate se polovi!
# Validation Loss: 0.0040
# Learning rate divider 7
# Vreme od pocetka simulacije: 654.8977723121643 sekundi
# Epoch 69/99
# ----------
# Training Loss: 0.0104
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0044
# Learning rate divider 7
# Vreme od pocetka simulacije: 664.3497712612152 sekundi
# Epoch 70/99
# ----------
# Training Loss: 0.0107
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0039
# Learning rate divider 7
# Vreme od pocetka simulacije: 673.9148645401001 sekundi
# Epoch 71/99
# ----------
# Training Loss: 0.0105
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0040
# Learning rate divider 7
# Vreme od pocetka simulacije: 683.4956846237183 sekundi
# Epoch 72/99
# ----------
# Training Loss: 0.0106
# Validation Loss: 0.0034
# Learning rate divider 7
# Vreme od pocetka simulacije: 693.0493490695953 sekundi
# Epoch 73/99
# ----------
# Training Loss: 0.0101
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0078
# Learning rate divider 7
# Vreme od pocetka simulacije: 702.4870316982269 sekundi
# Epoch 74/99
# ----------
# Training Loss: 0.0106
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0050
# Learning rate divider 7
# Vreme od pocetka simulacije: 712.0062460899353 sekundi
# Epoch 75/99
# ----------
# Training Loss: 0.0104
# Trenutni model nije sacuvan jer je loss veci sad
# Validation Loss: 0.0058
# Learning rate divider 7
# Vreme od pocetka simulacije: 721.5474650859833 sekundi
# Epoch 76/99
# ----------
# Training Loss: 0.0108
# Trenutni model nije sacuvan jer je loss veci sad
# Learning rate se polovi!
# Validation Loss: 0.0043
# Learning rate divider 8
# Broj polovljenja: 7

# %%
plt.subplots_adjust(wspace=1, hspace=1)
fig, ax = plt.subplots(nrows=1, ncols=2)
#keys = list(metrics.keys())
cnt = 0
print(metrics)
print("Best epoch is:",best_epoch)
for col in ax:
    col.set_title(keys[cnt])
    col.plot(metrics[keys[cnt]][3:40])
    cnt += 1
# Out:
# defaultdict(<class 'list'>, {'train_loss': [0.22836960408543475, 0.07782676328847918, 0.046725537201662615, 0.033345303356452215, 0.026582562289030963, 0.022474547073861317, 0.019589105906817623, 0.018104372635473598, 0.016927329893909476, 0.015934653363036896, 0.015121795848153992, 0.014749994758249627, 0.014382869604035156, 0.014013927821686012, 0.013731565217664986, 0.013475702106534215, 0.013259600644227753, 0.013361250108220252, 0.012816873767441783, 0.0128961150159481, 0.012783145138285554, 0.012555877990668164, 0.012333460512642417, 0.012309803874699201, 0.012012730013327002, 0.011825686895084637, 0.011930137602709064, 0.011830705900856662, 0.011709685613850173, 0.011790579925425176, 0.011668765469749418, 0.011550316486439813, 0.011555652035002001, 0.01135859015496159, 0.011325964693324747, 0.01127987144113478, 0.011431814216494935, 0.011290060390337923, 0.01122951846113916, 0.011149118992996603, 0.011051336835190436, 0.011107181565622725, 0.011147684167385602, 0.011241298333848505, 0.011373360020436573, 0.011085540732041144, 0.01098239976675402, 0.010899667830837357, 0.010898400695068087, 0.01146144069057695, 0.011526312681271423, 0.011149927869820804, 0.011287738330953477, 0.01135708097988339, 0.010788343922827511, 0.010844203222670016, 0.010730559641410072, 0.010617310786379383, 0.01071491432257063, 0.010648721545279946, 0.01040072579393521, 0.010594142057750156, 0.010636751520244916, 0.010835309098686813, 0.011097903270417056, 0.010656817378565553, 0.011043679973485368, 0.010712398962898263, 0.010484164472813709, 0.010429725860411269, 0.010721032957501979, 0.01053646933294779, 0.010551966563097103, 0.010149462774694777, 0.01057862955828536, 0.010434425132264703, 0.010769317020275006], 'val_loss': [0.11945860203516803, 0.04556111860733961, 0.02508946876429136, 0.019105941472805324, 0.014068202979817463, 0.012322212328857806, 0.00938580402971386, 0.008357923276428246, 0.007579481002497483, 0.006888020933634948, 0.007108833858546869, 0.006142705963086459, 0.006106378076924674, 0.0071642500627727805, 0.00544963261889668, 0.00623475092101751, 0.005793899207894731, 0.00541479680166236, 0.00673778462862748, 0.004957911711776443, 0.005204187017593538, 0.005050033343095827, 0.0050591136738981305, 0.005328183340841468, 0.004781221590186772, 0.004570221935531017, 0.004452817219809275, 0.0042980877196907305, 0.0057052604981386425, 0.005036502793410571, 0.004237218375288746, 0.005069053284293431, 0.004675452291366124, 0.004233305728824974, 0.00425004828689848, 0.004877047534988075, 0.004967195783274341, 0.004058909500412439, 0.004160339688263956, 0.004044218672797783, 0.003967553452335697, 0.003942801549747724, 0.004584549847100956, 0.005345577335002784, 0.004038411283709919, 0.003991335185149893, 0.003931851142843795, 0.003878950490424735, 0.0067627243015015055, 0.004172577109710274, 0.004283382753350372, 0.00628683075569065, 0.004957894002804755, 0.004380891284072008, 0.004512794452076441, 0.004192449001850254, 0.0037147637847291088, 0.0037257114668527483, 0.0053367904896109855, 0.00409846414727426, 0.003705427359107299, 0.0038557359367965556, 0.006952490257210753, 0.004411384274240188, 0.0039201069180950085, 0.005967403880868441, 0.0045933615764576705, 0.0038346786901390507, 0.004044658666616726, 0.00436563201550545, 0.003940066088915823, 0.0040222253215621215, 0.00344127364136315, 0.007762663858621609, 0.004960525261680235, 0.005822049533027811], 'train': []})
# Best epoch is: 72

# %%
beg = 1
end = 35
plt.plot(metrics['train_loss'][beg:end])
plt.plot(metrics['val_loss'][beg:end])
plt.title("Train and validation loss of CNN model")
plt.legend(['train loss', 'validation loss'])
plt.xlabel('N')
plt.ylabel('Loss')
plt.savefig('CNN_loss.png', dpi = 90)
plt.show()

# %%
speach_filenames_test
# Out:
# array(['../../dataset/en/clips\\common_voice_en_18453744.mp3',
#        '../../dataset/en/clips\\common_voice_en_127444.mp3'], dtype='<U51')

# %%
model3=torch.load("C:\\Users\\psiml\\Desktop\\model\\model.pth")
#model = TheModelClass(*args, **kwargs)
#model.load_state_dict(torch.load("C:\\Users\\psiml\\Desktop\\model\\model.pth"))

# %%
model2
# Out:
# OrderedDict([('2.weight',
#               tensor([[[[-2.1364e-01, -3.6195e-01, -2.8195e-01,  ..., -4.2636e-01,
#                          -4.3159e-01, -5.3954e-01],
#                         [ 1.7942e-01,  6.8752e-02, -1.4616e-02,  ..., -7.0994e-02,
#                          -1.2457e-01, -2.8831e-01],
#                         [ 2.8179e-01,  9.1423e-02,  4.1816e-02,  ...,  1.3120e-01,
#                           1.8940e-01,  4.2345e-02],
#                         ...,
#                         [ 1.3742e-01,  4.5056e-02, -7.9283e-02,  ...,  2.5795e-01,
#                           7.0045e-02, -9.6678e-02],
#                         [-6.2777e-03, -1.1530e-01,  2.4537e-02,  ...,  1.1392e-01,
#                           4.4201e-03,  2.0985e-01],
#                         [ 2.4196e-02,  1.1799e-02,  2.0957e-02,  ...,  1.3630e-01,
#                           3.8654e-02,  5.3105e-02]]],
#
#
#                       [[[ 1.1326e-01,  1.2365e-01,  3.5029e-02,  ...,  4.2054e-02,
#                           2.3521e-02, -9.3548e-02],
#                         [ 8.9418e-02, -9.6368e-02,  1.0445e-02,  ...,  5.9722e-02,
#                          -4.1417e-02, -1.5085e-01],
#                         [ 1.2448e-01,  1.4225e-01,  1.0782e-01,  ...,  5.0781e-02,
#                          -1.0288e-01, -8.2980e-02],
#                         ...,
#                         [ 3.0394e-02,  2.9582e-02, -3.7024e-02,  ...,  8.4041e-02,
#                          -3.4581e-02, -1.8726e-01],
#                         [ 2.9257e-02, -2.2147e-02, -9.2353e-02,  ..., -8.6149e-02,
#                           6.4678e-02, -3.9600e-01],
#                         [ 9.3564e-02,  3.6452e-02, -1.3084e-01,  ..., -1.2346e-01,
#                           1.4380e-01,  1.0115e-01]]],
#
#
#                       [[[ 1.0703e-01,  2.8142e-02, -3.0486e-02,  ...,  3.0437e-02,
#                          -3.4609e-02,  2.3460e-01],
#                         [ 3.8870e-02,  8.0659e-02,  2.6216e-01,  ..., -4.0269e-02,
#                           7.2250e-02,  3.0195e-01],
#                         [ 9.7771e-02,  7.2357e-03, -9.9674e-02,  ...,  2.8140e-02,
#                          -7.5862e-02,  9.9884e-02],
#                         ...,
#                         [-8.4154e-02, -1.5170e-01,  8.2243e-02,  ...,  5.9084e-02,
#                          -3.2469e-02,  1.0977e-01],
#                         [ 8.1445e-02, -4.4532e-02, -1.9415e-01,  ...,  1.0788e-01,
#                          -6.0751e-02, -7.2274e-02],
#                         [ 1.7429e-01,  1.7458e-01,  1.8583e-01,  ...,  1.8682e-03,
#                           3.1068e-01,  3.0237e-01]]],
#
#
#                       ...,
#
#
#                       [[[ 4.6160e-02,  3.4125e-02, -1.6276e-01,  ...,  1.1543e-01,
#                           2.2184e-02, -7.6056e-02],
#                         [ 8.2346e-02,  1.3135e-01,  4.8940e-02,  ...,  5.5929e-02,
#                          -7.1092e-03, -1.0401e-01],
#                         [ 5.6084e-02,  1.3258e-01,  8.1404e-02,  ..., -6.5101e-02,
#                           3.2642e-01,  7.0519e-03],
#                         ...,
#                         [ 2.3961e-01,  2.4042e-01,  2.1180e-01,  ...,  1.4172e-01,
#                           3.6489e-02, -1.8679e-01],
#                         [ 9.4913e-02,  6.8038e-02,  9.4088e-02,  ...,  1.5945e-01,
#                           1.9822e-01, -2.6485e-01],
#                         [ 1.1564e-01, -1.9823e-01, -1.0099e-01,  ...,  2.1787e-01,
#                           1.0450e-01, -2.0235e-01]]],
#
#
#                       [[[ 4.4337e-02, -1.1288e-02, -1.5867e-02,  ...,  3.5319e-03,
#                           1.4307e-02,  5.1966e-02],
#                         [ 1.5884e-02, -9.5605e-03,  9.3483e-02,  ...,  1.1392e-01,
#                          -3.3157e-02,  1.6391e-01],
#                         [-2.6743e-01, -1.6319e-01, -1.9009e-01,  ..., -4.3881e-01,
#                          -2.9616e-01, -9.3466e-02],
#                         ...,
#                         [-1.1136e-02, -4.4598e-02, -1.6561e-02,  ...,  3.2939e-02,
#                           8.3450e-02, -8.6510e-02],
#                         [-2.9810e-02, -9.9994e-02, -3.8169e-02,  ..., -1.2020e-02,
#                          -1.6830e-02,  9.5912e-02],
#                         [ 8.5253e-04, -1.1153e-02,  5.8288e-02,  ...,  9.8451e-02,
#                          -9.2784e-02,  2.9008e-02]]],
#
#
#                       [[[-6.4385e-02,  5.8929e-02, -4.4695e-02,  ..., -5.3318e-02,
#                          -2.0057e-02, -4.2175e-02],
#                         [ 1.1852e-01,  1.1126e-01, -6.6038e-02,  ..., -1.3195e-02,
#                          -1.2802e-01,  6.1353e-02],
#                         [ 1.4130e-01,  1.5228e-01,  9.3525e-02,  ...,  1.0057e-02,
#                           5.9530e-02,  3.7625e-02],
#                         ...,
#                         [-1.7619e-01,  1.6442e-01, -9.6152e-02,  ...,  3.3761e-02,
#                          -1.5966e-01,  1.2936e-01],
#                         [-2.0479e-01,  3.9990e-04, -6.9328e-02,  ...,  6.1347e-02,
#                           2.2351e-02,  1.8011e-01],
#                         [-1.3918e-01, -8.5387e-03, -1.4418e-01,  ...,  3.8608e-02,
#                          -1.8005e-02,  7.3322e-02]]]], device='cuda:0')),
#              ('4.weight',
#               tensor([1.0755, 1.1346, 1.0359, 0.9028, 0.8803, 0.8989, 1.1252, 0.9137, 0.9444,
#                       1.0494, 0.8170, 1.0886, 1.0158, 1.0552, 1.0876, 1.0102, 0.9591, 1.0041],
#                      device='cuda:0')),
#              ('4.bias',
#               tensor([-0.1437,  0.0351, -0.0557, -0.0356, -0.1639, -0.0178,  0.0040,  0.1381,
#                        0.0928, -0.1104,  0.0688,  0.1260, -0.0478,  0.0184, -0.2284, -0.0369,
#                        0.0243, -0.1182], device='cuda:0')),
#              ('4.running_mean',
#               tensor([0.0439, 0.2035, 0.3435, 0.0526, 0.0162, 0.6313, 0.1615, 0.0314, 0.0849,
#                       0.0729, 0.0352, 0.2781, 0.2125, 0.1954, 0.1325, 0.3146, 0.0129, 0.1360],
#                      device='cuda:0')),
#              ('4.running_var',
#               tensor([0.0828, 0.2882, 0.5060, 0.0605, 0.0186, 1.9220, 0.1690, 0.0334, 0.1013,
#                       0.1098, 0.0256, 0.4953, 0.2852, 0.2115, 0.1447, 0.5864, 0.0113, 0.1831],
#                      device='cuda:0')),
#              ('4.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('6.weight',
#               tensor([[[[-1.7590e-02,  7.8847e-04, -1.0071e-01, -1.8378e-01,  5.3657e-02]],
#
#                        [[ 2.1260e-01,  2.5897e-01, -8.3060e-02,  1.4659e-01,  4.5689e-02]],
#
#                        [[-1.1217e-02, -1.0702e-01, -3.7778e-02,  1.7557e-02, -5.2067e-02]],
#
#                        ...,
#
#                        [[ 2.4635e-01,  4.5966e-02, -9.5902e-02, -2.4116e-01, -2.1714e-01]],
#
#                        [[-1.6543e-01,  1.2120e-01, -1.0107e-01,  2.0717e-01,  4.2431e-02]],
#
#                        [[ 1.6767e-02,  6.6319e-02,  6.5623e-02, -1.6177e-02, -2.5030e-03]]],
#
#
#                       [[[-2.0687e-01,  3.4122e-02, -5.3583e-03,  8.2397e-02,  1.6988e-01]],
#
#                        [[ 3.0225e-02,  4.7685e-02, -1.2051e-01,  5.2620e-02, -1.0625e-01]],
#
#                        [[-1.8159e-02, -7.3171e-02,  3.4193e-02,  7.6961e-03,  6.8782e-02]],
#
#                        ...,
#
#                        [[ 3.6269e-02,  8.2301e-04, -1.8666e-01, -2.5097e-01, -4.6756e-02]],
#
#                        [[ 4.1844e-02,  1.2333e-01,  1.3021e-01,  1.6470e-01, -9.4338e-02]],
#
#                        [[-4.0755e-02, -2.5915e-01, -2.2834e-02,  5.8717e-02,  1.8867e-02]]],
#
#
#                       [[[ 2.3755e-02,  8.0665e-02, -1.7704e-05,  2.1996e-02,  2.3339e-01]],
#
#                        [[-9.7696e-02, -2.1159e-02, -9.2284e-02, -2.0289e-01, -2.9127e-02]],
#
#                        [[-4.0735e-02,  8.0460e-02, -1.0179e-01, -5.6268e-02,  1.2234e-01]],
#
#                        ...,
#
#                        [[ 1.3960e-01,  1.9501e-02,  9.9100e-02,  2.1633e-03, -7.9413e-04]],
#
#                        [[ 1.3744e-01,  1.3353e-01,  1.6497e-01, -2.3459e-01,  4.2136e-02]],
#
#                        [[-1.4755e-01, -1.9182e-01, -8.4963e-02,  8.5161e-02,  1.1176e-01]]],
#
#
#                       ...,
#
#
#                       [[[ 4.6279e-02,  2.8426e-02, -3.8835e-02, -6.6783e-02, -1.0489e-01]],
#
#                        [[-4.7020e-02,  4.7344e-02,  1.8550e-01,  1.1842e-01, -4.5578e-02]],
#
#                        [[ 8.5447e-02,  4.4149e-02, -1.8220e-01,  3.3812e-02,  8.6055e-02]],
#
#                        ...,
#
#                        [[ 2.3001e-02,  1.9187e-01,  1.0377e-01, -5.7892e-02, -1.5715e-01]],
#
#                        [[-1.3793e-01,  7.6364e-02, -6.5494e-02, -8.0165e-02,  1.5195e-01]],
#
#                        [[-4.0328e-02, -3.0228e-01,  1.5202e-01, -2.7714e-01, -2.4737e-02]]],
#
#
#                       [[[ 4.1714e-02,  9.7344e-02,  1.5134e-01,  9.1618e-02, -1.3682e-01]],
#
#                        [[-4.6868e-02,  7.6774e-02, -5.9819e-02,  1.7579e-01, -1.0641e-01]],
#
#                        [[ 2.7640e-01,  2.2071e-01, -1.1052e-01,  1.1316e-01,  4.8479e-02]],
#
#                        ...,
#
#                        [[ 1.9755e-04, -1.5783e-01, -3.0924e-02,  7.9039e-02, -3.9685e-02]],
#
#                        [[-1.4233e-01, -7.5158e-02, -9.2172e-02,  2.0247e-01, -1.5738e-01]],
#
#                        [[-2.9581e-02,  1.2976e-01, -1.0045e-01, -1.4510e-02, -6.5072e-02]]],
#
#
#                       [[[-1.6480e-02,  1.5704e-01, -1.0841e-01,  7.1966e-02, -3.5167e-02]],
#
#                        [[-2.3940e-01, -2.4918e-02, -1.6595e-01,  1.3242e-01,  5.6529e-02]],
#
#                        [[ 3.3433e-02,  1.0261e-01, -1.4471e-01, -2.7302e-02,  2.3556e-01]],
#
#                        ...,
#
#                        [[-4.9416e-03,  2.9059e-02, -3.2512e-02,  2.6147e-01, -1.0342e-01]],
#
#                        [[ 1.6495e-01,  2.0690e-02,  2.9973e-02,  1.0025e-01,  1.0211e-01]],
#
#                        [[ 9.6675e-02,  1.8395e-01,  1.5276e-01, -3.2720e-02,  6.0708e-02]]]],
#                      device='cuda:0')),
#              ('8.weight',
#               tensor([0.9439, 0.9957, 0.9463, 0.9738, 1.2313, 0.9990, 1.1111, 0.9642, 1.1127,
#                       1.0635, 0.9393, 1.1099, 0.9671, 0.9229, 0.9503, 0.9150, 0.9296, 0.9153,
#                       1.1634, 0.9928, 1.0524, 0.9600, 1.0015, 0.8957, 1.0666, 1.0701, 0.9082,
#                       1.0336, 0.8804, 1.1054], device='cuda:0')),
#              ('8.bias',
#               tensor([-0.2505, -0.1101, -0.0063, -0.0160, -0.2287, -0.1773, -0.2820,  0.0226,
#                       -0.1068, -0.0964,  0.0047, -0.0922, -0.1682, -0.2226, -0.0450, -0.0812,
#                       -0.2629, -0.0853, -0.2859,  0.2659, -0.2225, -0.0107, -0.1124, -0.1847,
#                       -0.1361, -0.1374, -0.0326, -0.0526, -0.1615, -0.0915], device='cuda:0')),
#              ('8.running_mean',
#               tensor([0.2322, 0.3748, 0.1160, 0.4921, 0.2910, 0.2381, 0.5277, 0.1953, 0.2960,
#                       0.2037, 0.2131, 0.6154, 0.1818, 0.4351, 0.5223, 0.2566, 0.6584, 0.1854,
#                       0.8548, 0.0916, 0.4817, 0.3192, 0.4103, 0.2677, 0.4135, 0.1865, 0.3395,
#                       0.2301, 0.3138, 0.2383], device='cuda:0')),
#              ('8.running_var',
#               tensor([0.4893, 0.1939, 0.3487, 0.3935, 0.2042, 0.4619, 0.1759, 0.1670, 0.2422,
#                       0.2242, 0.6709, 0.2815, 0.6776, 0.1194, 0.6094, 0.7745, 4.7542, 0.5666,
#                       0.3219, 0.2661, 0.1821, 0.3127, 2.3314, 0.8805, 0.0958, 0.2847, 0.5361,
#                       0.4318, 1.0216, 0.7420], device='cuda:0')),
#              ('8.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('10.weight',
#               tensor([[[[-0.0090,  0.0662, -0.0520,  ...,  0.0206,  0.1764,  0.0252]],
#
#                        [[ 0.0273, -0.0262,  0.1533,  ...,  0.1357, -0.0040,  0.0412]],
#
#                        [[ 0.0482,  0.0916,  0.1184,  ..., -0.1274,  0.2384, -0.0063]],
#
#                        ...,
#
#                        [[-0.0402,  0.0554, -0.0645,  ...,  0.1567, -0.0668,  0.0069]],
#
#                        [[ 0.0194, -0.0131, -0.0623,  ..., -0.0746, -0.0261, -0.0664]],
#
#                        [[ 0.1457,  0.1434,  0.0329,  ..., -0.1481,  0.0260,  0.1484]]],
#
#
#                       [[[ 0.0411,  0.0188, -0.0215,  ..., -0.0025,  0.0063, -0.0089]],
#
#                        [[-0.0435, -0.1750,  0.2076,  ...,  0.1041,  0.0288, -0.0032]],
#
#                        [[-0.0610,  0.0237, -0.1503,  ...,  0.0291,  0.2057,  0.0039]],
#
#                        ...,
#
#                        [[-0.1002, -0.0406,  0.1026,  ...,  0.0889, -0.1633,  0.0912]],
#
#                        [[-0.0704,  0.0217, -0.0792,  ..., -0.0175, -0.1544,  0.0913]],
#
#                        [[ 0.0288,  0.0897, -0.0108,  ..., -0.0332,  0.0440,  0.1403]]],
#
#
#                       [[[-0.1334, -0.0269, -0.0524,  ..., -0.0133,  0.0292, -0.0285]],
#
#                        [[-0.1524, -0.0683, -0.0512,  ..., -0.0257,  0.1717, -0.1682]],
#
#                        [[ 0.0823, -0.0498, -0.0168,  ...,  0.0077,  0.0221,  0.1786]],
#
#                        ...,
#
#                        [[-0.1053, -0.1027, -0.1288,  ..., -0.0112, -0.2595, -0.0949]],
#
#                        [[ 0.0019, -0.1654, -0.0014,  ...,  0.0194, -0.0553, -0.0256]],
#
#                        [[-0.0062, -0.0823, -0.0658,  ...,  0.0219, -0.1337,  0.0872]]],
#
#
#                       ...,
#
#
#                       [[[-0.0966, -0.0311,  0.1105,  ..., -0.0663,  0.1014,  0.0791]],
#
#                        [[-0.0174, -0.0418,  0.1815,  ..., -0.0271,  0.1483,  0.0392]],
#
#                        [[-0.0612,  0.0659, -0.0289,  ..., -0.0947,  0.0287,  0.1021]],
#
#                        ...,
#
#                        [[-0.0829, -0.0568,  0.0779,  ...,  0.0102,  0.1397, -0.0846]],
#
#                        [[-0.0307,  0.0422,  0.1030,  ..., -0.0443,  0.0444,  0.0163]],
#
#                        [[ 0.0177,  0.1137,  0.1240,  ..., -0.1374,  0.0360, -0.1190]]],
#
#
#                       [[[ 0.0793,  0.0258, -0.0835,  ...,  0.0273, -0.0280, -0.0046]],
#
#                        [[-0.0775, -0.1013, -0.0259,  ...,  0.0020, -0.0757,  0.0767]],
#
#                        [[-0.1498,  0.0190, -0.0358,  ...,  0.0119, -0.0154, -0.1214]],
#
#                        ...,
#
#                        [[-0.1712, -0.1753, -0.0785,  ...,  0.1142,  0.1047, -0.1595]],
#
#                        [[-0.3151, -0.1779,  0.0588,  ...,  0.2384, -0.1208, -0.0960]],
#
#                        [[ 0.1138,  0.0822, -0.1078,  ...,  0.2135, -0.0421, -0.1870]]],
#
#
#                       [[[ 0.0536,  0.0297,  0.0951,  ...,  0.0055, -0.1941, -0.1551]],
#
#                        [[ 0.0757,  0.0327,  0.0092,  ...,  0.1418, -0.0348,  0.1526]],
#
#                        [[-0.0860, -0.0779, -0.0601,  ...,  0.0243,  0.1165, -0.0462]],
#
#                        ...,
#
#                        [[-0.0481,  0.0263, -0.0098,  ..., -0.0230, -0.1067, -0.0115]],
#
#                        [[-0.0561,  0.1701,  0.0783,  ...,  0.0433, -0.0571,  0.0075]],
#
#                        [[ 0.0984,  0.1180, -0.1651,  ...,  0.0013, -0.1162, -0.1335]]]],
#                      device='cuda:0')),
#              ('12.weight',
#               tensor([0.9272, 1.0580, 0.9973, 0.9223, 1.0127, 1.0067, 0.9996, 1.0673],
#                      device='cuda:0')),
#              ('12.bias',
#               tensor([-0.2064, -0.0345,  0.0240, -0.0413,  0.0144, -0.0535, -0.2197, -0.1410],
#                      device='cuda:0')),
#              ('12.running_mean',
#               tensor([0.3842, 0.6200, 0.9018, 0.3871, 0.3492, 0.4227, 0.8503, 0.7259],
#                      device='cuda:0')),
#              ('12.running_var',
#               tensor([1.5948, 1.7254, 2.2732, 3.1347, 2.5914, 2.2640, 2.4086, 1.4326],
#                      device='cuda:0')),
#              ('12.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('14.weight',
#               tensor([[[[-2.1234e-01, -1.3883e-01, -3.2229e-02,  ..., -2.4557e-01,
#                          -3.5835e-02,  1.8790e-02]],
#
#                        [[-1.9805e-01, -1.0731e-01,  4.3260e-02,  ..., -2.6376e-01,
#                           7.2846e-02,  1.5718e-01]],
#
#                        [[-1.7218e-01,  1.1334e-01, -1.2501e-02,  ..., -6.6026e-02,
#                          -3.7956e-02, -7.4586e-02]],
#
#                        ...,
#
#                        [[-1.7872e-01, -1.5661e-01, -1.2990e-01,  ...,  2.1984e-02,
#                          -8.8490e-02,  1.2397e-01]],
#
#                        [[-2.9523e-01, -5.9756e-02,  1.1062e-01,  ..., -1.0023e-01,
#                           1.7306e-01,  1.8108e-01]],
#
#                        [[-1.6289e-01,  8.7709e-02,  1.1625e-01,  ..., -9.2917e-03,
#                           1.7269e-01,  1.5428e-01]]],
#
#
#                       [[[-2.0317e-01, -1.8616e-01, -2.5871e-01,  ..., -1.1565e-01,
#                           3.5517e-02,  2.1422e-01]],
#
#                        [[-3.1758e-03,  1.1101e-01, -1.1633e-01,  ..., -1.5039e-01,
#                          -1.7415e-01,  7.2325e-02]],
#
#                        [[ 3.8401e-02,  2.8321e-01,  1.0846e-01,  ..., -1.7321e-01,
#                           3.4410e-03,  1.5137e-01]],
#
#                        ...,
#
#                        [[-5.5183e-02, -3.5258e-04, -1.0408e-01,  ...,  7.7649e-02,
#                           7.1691e-04, -4.0609e-02]],
#
#                        [[-6.8787e-02,  2.2158e-01, -9.1239e-02,  ...,  1.4995e-01,
#                           1.8411e-01, -3.6813e-02]],
#
#                        [[-6.8532e-02, -2.1068e-01,  5.6535e-02,  ..., -8.7545e-03,
#                           1.4945e-01,  9.7355e-02]]],
#
#
#                       [[[ 2.1970e-01,  1.2503e-01,  1.8034e-02,  ..., -2.0572e-01,
#                           7.3751e-02, -9.5043e-02]],
#
#                        [[ 5.5104e-02,  7.9832e-03, -1.1199e-01,  ..., -2.8920e-02,
#                           3.5838e-02,  1.3034e-01]],
#
#                        [[ 1.6125e-01, -1.1444e-01,  7.6280e-02,  ...,  6.6959e-02,
#                          -3.1942e-02,  8.4782e-02]],
#
#                        ...,
#
#                        [[-1.5704e-01, -3.0970e-01, -3.7326e-01,  ..., -5.4110e-02,
#                           1.0777e-01, -2.3708e-01]],
#
#                        [[ 3.5590e-03,  1.3292e-03,  6.5487e-02,  ..., -6.4445e-02,
#                          -1.2588e-02, -8.1837e-03]],
#
#                        [[-3.9462e-01, -1.2070e-01,  1.2144e-01,  ..., -6.0794e-03,
#                           1.6225e-02,  1.6058e-01]]],
#
#
#                       ...,
#
#
#                       [[[-2.2349e-02,  2.6816e-02,  1.2128e-01,  ..., -5.2272e-02,
#                          -1.8304e-01,  1.1092e-01]],
#
#                        [[ 9.1911e-02, -1.1537e-01,  7.0871e-02,  ..., -5.8916e-02,
#                           2.9233e-02, -3.4048e-01]],
#
#                        [[-2.4373e-01,  1.2004e-01, -7.6434e-02,  ...,  2.0403e-02,
#                          -3.6529e-02, -1.3782e-02]],
#
#                        ...,
#
#                        [[ 1.1884e-01,  2.8302e-02,  1.5596e-01,  ...,  2.5655e-01,
#                           6.5507e-02, -8.9642e-02]],
#
#                        [[ 9.9358e-02,  6.0627e-02, -6.3133e-02,  ..., -6.0729e-02,
#                           1.2248e-01,  8.5541e-02]],
#
#                        [[ 1.0099e-01, -1.5479e-02, -1.3565e-01,  ..., -2.2717e-01,
#                          -4.1018e-02, -5.8581e-02]]],
#
#
#                       [[[ 1.2529e-01, -4.8884e-02, -1.1492e-01,  ...,  1.1183e-01,
#                          -1.4870e-01,  7.5657e-02]],
#
#                        [[ 1.6251e-01,  9.7283e-02, -3.1201e-02,  ...,  7.1396e-02,
#                          -1.1235e-01,  1.1660e-01]],
#
#                        [[-1.6699e-01, -3.0413e-01, -1.0901e-01,  ..., -2.2479e-01,
#                           1.2150e-01,  1.0388e-01]],
#
#                        ...,
#
#                        [[-2.2289e-01,  9.8861e-02,  1.1066e-01,  ..., -4.0906e-02,
#                          -1.2604e-02,  1.4574e-01]],
#
#                        [[-3.0915e-02, -4.0075e-03,  6.3318e-02,  ..., -1.1332e-01,
#                           1.0490e-01,  8.2010e-02]],
#
#                        [[-1.5262e-01, -9.3292e-02,  1.3539e-01,  ..., -9.5647e-02,
#                           5.3080e-02,  3.1269e-03]]],
#
#
#                       [[[ 1.7565e-01, -8.0391e-03,  1.1183e-01,  ..., -1.1604e-01,
#                           1.3872e-01, -7.0304e-02]],
#
#                        [[ 1.4141e-01, -2.3086e-02,  2.4332e-02,  ..., -1.1346e-01,
#                           5.7556e-02, -1.3393e-01]],
#
#                        [[ 5.1104e-02, -3.9783e-03,  1.7950e-01,  ..., -6.4597e-02,
#                           1.0019e-01,  1.6678e-01]],
#
#                        ...,
#
#                        [[-1.6624e-01, -2.4471e-02,  4.6948e-02,  ..., -1.9455e-01,
#                          -1.3330e-02,  2.2137e-02]],
#
#                        [[-2.8452e-02,  6.9860e-02,  4.5673e-02,  ...,  1.4981e-01,
#                          -1.5281e-01,  8.3488e-02]],
#
#                        [[ 2.0455e-02, -5.9819e-02,  7.2625e-02,  ...,  1.2045e-02,
#                          -4.4082e-03,  4.8153e-03]]]], device='cuda:0')),
#              ('16.weight',
#               tensor([0.9252, 1.0698, 1.1689, 0.8259, 0.9344, 0.8774, 0.9380, 1.0572, 0.9747,
#                       1.0408, 0.9844, 0.9882, 1.1055, 0.8832, 1.1454, 1.1007, 0.9692, 0.9449],
#                      device='cuda:0')),
#              ('16.bias',
#               tensor([ 0.0281,  0.1565,  0.0065,  0.1150,  0.0219, -0.0925,  0.0700, -0.0340,
#                        0.1966,  0.0300, -0.0976,  0.0416,  0.0867, -0.1218, -0.2041,  0.0313,
#                        0.0181,  0.0470], device='cuda:0')),
#              ('16.running_mean',
#               tensor([0.2437, 0.4279, 0.2723, 0.1689, 0.1481, 0.2847, 0.2463, 0.3464, 0.2844,
#                       0.3306, 0.4028, 0.3768, 0.5818, 0.2756, 0.3018, 0.3017, 0.3280, 0.2364],
#                      device='cuda:0')),
#              ('16.running_var',
#               tensor([0.3021, 0.3556, 0.1357, 0.2431, 0.1971, 0.8089, 0.1949, 0.2176, 0.2475,
#                       0.4789, 0.6730, 0.4953, 0.3954, 0.4625, 0.1359, 0.1491, 0.1757, 0.6543],
#                      device='cuda:0')),
#              ('16.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('17.weight',
#               tensor([[[[-0.0572, -0.0348, -0.0243, -0.0539, -0.1030]],
#
#                        [[ 0.0611, -0.1045, -0.0697,  0.2098,  0.1731]],
#
#                        [[ 0.2114, -0.0343, -0.0817,  0.0027, -0.0100]],
#
#                        ...,
#
#                        [[ 0.0418, -0.1735, -0.2446, -0.0641, -0.0742]],
#
#                        [[-0.2106, -0.1733,  0.0936, -0.2220, -0.1110]],
#
#                        [[-0.0119,  0.0825,  0.0379, -0.1133, -0.2818]]],
#
#
#                       [[[-0.1004, -0.0945,  0.1510, -0.0332, -0.1138]],
#
#                        [[-0.1710, -0.0092,  0.0477, -0.1985,  0.0426]],
#
#                        [[-0.0229, -0.0228,  0.0910, -0.1106, -0.0178]],
#
#                        ...,
#
#                        [[ 0.1203, -0.1151,  0.0649, -0.0070,  0.0206]],
#
#                        [[-0.0413,  0.0687,  0.1112,  0.0841,  0.0614]],
#
#                        [[-0.0335,  0.0346, -0.0461, -0.0558, -0.1679]]],
#
#
#                       [[[ 0.0035,  0.0846, -0.2265,  0.0219,  0.0525]],
#
#                        [[ 0.0992, -0.1849, -0.0098,  0.1562, -0.1742]],
#
#                        [[-0.1257, -0.0173, -0.0575,  0.1565, -0.0476]],
#
#                        ...,
#
#                        [[-0.2575,  0.0323, -0.1968,  0.0694, -0.1030]],
#
#                        [[-0.0811,  0.1374, -0.1688, -0.0392, -0.1168]],
#
#                        [[-0.0543,  0.1872, -0.0898,  0.2416, -0.2538]]],
#
#
#                       ...,
#
#
#                       [[[-0.0839, -0.0731, -0.0493, -0.1117,  0.0507]],
#
#                        [[ 0.0125, -0.0751, -0.1157,  0.1802,  0.0104]],
#
#                        [[-0.2820, -0.1816, -0.0240,  0.0754,  0.2146]],
#
#                        ...,
#
#                        [[ 0.1324, -0.2645, -0.0031, -0.0030, -0.0821]],
#
#                        [[-0.2147,  0.0531,  0.1105,  0.0445,  0.0215]],
#
#                        [[ 0.0924, -0.0916, -0.0584, -0.1475, -0.0553]]],
#
#
#                       [[[ 0.0048, -0.1192,  0.0675, -0.0166,  0.2627]],
#
#                        [[ 0.0207, -0.1783, -0.1109, -0.0564,  0.2073]],
#
#                        [[ 0.0680,  0.0575, -0.2403, -0.0240,  0.2254]],
#
#                        ...,
#
#                        [[-0.0228, -0.0164,  0.0240, -0.1363, -0.0023]],
#
#                        [[ 0.2189,  0.0110,  0.0927,  0.0714,  0.0774]],
#
#                        [[ 0.0608, -0.0917,  0.0666,  0.0389, -0.0870]]],
#
#
#                       [[[-0.2287, -0.1974,  0.0322, -0.0254,  0.1544]],
#
#                        [[-0.0774, -0.1021, -0.2233,  0.0704, -0.0893]],
#
#                        [[-0.0517, -0.1782, -0.0208,  0.0349,  0.0012]],
#
#                        ...,
#
#                        [[ 0.0418,  0.3146, -0.1948,  0.0690, -0.1003]],
#
#                        [[-0.2253, -0.1020, -0.0723,  0.1524, -0.0296]],
#
#                        [[-0.0418,  0.0880, -0.1121,  0.0668, -0.1692]]]], device='cuda:0')),
#              ('19.weight',
#               tensor([1.0391, 0.8309, 1.0621, 1.1102, 1.0746, 1.0325, 0.9232, 0.8993, 1.0748,
#                       0.9964, 1.1233, 1.1112, 0.9465, 1.0092, 0.9763, 1.1226, 0.9864, 0.9544,
#                       0.9777, 0.9945, 0.9583, 0.8901, 0.9872, 1.2320, 0.9074, 0.7906, 0.8606,
#                       1.0186, 1.0381, 1.0627], device='cuda:0')),
#              ('19.bias',
#               tensor([-0.1787, -0.0009,  0.0818,  0.0445, -0.0529, -0.1275, -0.1723,  0.0198,
#                       -0.1060,  0.1629,  0.0669, -0.1669, -0.1501, -0.0347, -0.0054, -0.0296,
#                        0.0162,  0.2125, -0.0192,  0.0617, -0.0776,  0.0350,  0.0335, -0.1291,
#                        0.0061, -0.0461,  0.0131, -0.0478,  0.0660,  0.0361], device='cuda:0')),
#              ('19.running_mean',
#               tensor([0.3967, 0.3193, 0.3247, 0.2522, 0.2100, 0.2396, 0.3570, 0.4417, 0.3858,
#                       0.4054, 0.5461, 0.2950, 0.3323, 0.3491, 0.3624, 0.2594, 0.3102, 0.3364,
#                       0.2674, 0.3525, 0.4120, 0.2345, 0.5405, 0.1706, 0.4674, 0.2620, 0.5440,
#                       0.4044, 0.3794, 0.3687], device='cuda:0')),
#              ('19.running_var',
#               tensor([0.3109, 0.4251, 0.3092, 0.1533, 0.2638, 0.2380, 0.3960, 1.1107, 0.1847,
#                       0.4792, 0.4720, 0.3328, 0.4931, 0.4539, 0.6176, 0.9053, 0.2279, 0.4816,
#                       0.2741, 0.3480, 1.1816, 0.2376, 1.6268, 0.1258, 0.8520, 0.3959, 2.0164,
#                       0.3325, 0.9054, 0.2277], device='cuda:0')),
#              ('19.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('20.weight',
#               tensor([[[[ 0.0751, -0.0386, -0.0885,  ..., -0.0073,  0.0223,  0.0368]],
#
#                        [[-0.0495, -0.1610,  0.0262,  ..., -0.0292, -0.1396,  0.0882]],
#
#                        [[ 0.1324,  0.0942,  0.0374,  ..., -0.1222,  0.0535,  0.0800]],
#
#                        ...,
#
#                        [[ 0.0773, -0.0009, -0.1382,  ..., -0.2215, -0.0054,  0.0602]],
#
#                        [[ 0.0775,  0.1163, -0.0668,  ...,  0.0287,  0.0303,  0.1133]],
#
#                        [[ 0.0540, -0.0522,  0.1063,  ..., -0.0353, -0.0195,  0.0282]]],
#
#
#                       [[[ 0.1892, -0.1394, -0.0099,  ...,  0.0383,  0.1137, -0.0576]],
#
#                        [[ 0.0037,  0.0180,  0.0380,  ..., -0.0194, -0.0093,  0.0859]],
#
#                        [[ 0.0179,  0.0969, -0.0405,  ..., -0.0455, -0.1218, -0.1875]],
#
#                        ...,
#
#                        [[ 0.0003,  0.0464, -0.0541,  ...,  0.0450,  0.0824, -0.0005]],
#
#                        [[ 0.0249, -0.0334, -0.0726,  ..., -0.0546, -0.0093,  0.0063]],
#
#                        [[-0.1032, -0.1116, -0.1026,  ..., -0.0317, -0.0328,  0.2044]]],
#
#
#                       [[[-0.0091, -0.1162, -0.0014,  ..., -0.0878, -0.0706, -0.0109]],
#
#                        [[-0.0514, -0.0178,  0.1120,  ..., -0.0532,  0.0463,  0.0320]],
#
#                        [[ 0.2022, -0.0599, -0.0943,  ...,  0.1120,  0.0373, -0.0418]],
#
#                        ...,
#
#                        [[ 0.0118, -0.0211, -0.1516,  ..., -0.0097, -0.0140, -0.1608]],
#
#                        [[ 0.1069,  0.0485, -0.0656,  ..., -0.0073, -0.1596,  0.1947]],
#
#                        [[ 0.0249,  0.0035,  0.0733,  ..., -0.0805, -0.1415, -0.1008]]],
#
#
#                       ...,
#
#
#                       [[[ 0.0090,  0.0527,  0.0750,  ...,  0.0863,  0.0422, -0.0266]],
#
#                        [[ 0.0010,  0.0274,  0.0082,  ...,  0.0320,  0.0639,  0.0323]],
#
#                        [[ 0.1421, -0.1797, -0.0390,  ...,  0.0204, -0.0669, -0.0388]],
#
#                        ...,
#
#                        [[ 0.0045,  0.0140, -0.1037,  ..., -0.0696, -0.0991, -0.0331]],
#
#                        [[-0.1052, -0.1373,  0.0122,  ..., -0.0324, -0.0181,  0.0110]],
#
#                        [[ 0.1101,  0.1080,  0.1092,  ...,  0.0242,  0.0818, -0.0535]]],
#
#
#                       [[[-0.0464,  0.0293,  0.0712,  ...,  0.0284, -0.0108, -0.0883]],
#
#                        [[-0.0320, -0.0159, -0.0152,  ...,  0.0554, -0.0555, -0.1030]],
#
#                        [[-0.0352, -0.0504, -0.0596,  ..., -0.0243, -0.0767,  0.0528]],
#
#                        ...,
#
#                        [[-0.0902, -0.0241, -0.0299,  ...,  0.0863,  0.1085, -0.0382]],
#
#                        [[ 0.0356, -0.0728,  0.0784,  ...,  0.0568,  0.0418,  0.1354]],
#
#                        [[ 0.1984,  0.0398, -0.0134,  ..., -0.1122,  0.0504,  0.0022]]],
#
#
#                       [[[-0.0677,  0.0930, -0.2212,  ...,  0.1208, -0.1584,  0.1345]],
#
#                        [[-0.0023,  0.0661,  0.0121,  ...,  0.1558, -0.0162,  0.1029]],
#
#                        [[-0.0874,  0.0801,  0.0122,  ..., -0.1029, -0.1795, -0.1206]],
#
#                        ...,
#
#                        [[-0.1328, -0.0243, -0.0863,  ...,  0.0111,  0.0489,  0.0111]],
#
#                        [[ 0.0229, -0.0289, -0.0502,  ...,  0.0895,  0.0054,  0.0475]],
#
#                        [[-0.0637, -0.0022,  0.0237,  ...,  0.0246, -0.0016, -0.0285]]]],
#                      device='cuda:0')),
#              ('22.weight',
#               tensor([0.9825, 1.0588, 1.0594, 1.0699, 0.9884, 0.8027, 0.9938, 0.9490],
#                      device='cuda:0')),
#              ('22.bias',
#               tensor([ 0.0039,  0.0654,  0.0818,  0.0362, -0.0150, -0.0691, -0.0609,  0.0078],
#                      device='cuda:0')),
#              ('22.running_mean',
#               tensor([0.8340, 0.3026, 0.7376, 0.7684, 0.6434, 0.7915, 0.7972, 0.6295],
#                      device='cuda:0')),
#              ('22.running_var',
#               tensor([2.3061, 1.6449, 2.4632, 2.5604, 5.1771, 1.7104, 1.7535, 1.2307],
#                      device='cuda:0')),
#              ('22.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('24.weight',
#               tensor([[[[-0.0580,  0.2185,  0.1565,  ..., -0.0592, -0.1012, -0.2002]],
#
#                        [[-0.0957, -0.0156,  0.0015,  ..., -0.0515,  0.0470, -0.0143]],
#
#                        [[-0.1493, -0.1036, -0.0098,  ...,  0.1490,  0.0212, -0.0740]],
#
#                        ...,
#
#                        [[ 0.0905, -0.0829, -0.1065,  ..., -0.0196, -0.0117, -0.1423]],
#
#                        [[-0.1390,  0.0078,  0.0303,  ..., -0.0046, -0.0901, -0.1766]],
#
#                        [[-0.0065, -0.0459,  0.1660,  ..., -0.0341,  0.1647,  0.2201]]],
#
#
#                       [[[-0.0579,  0.1732,  0.0738,  ...,  0.1402, -0.0653, -0.2091]],
#
#                        [[-0.0890,  0.0322, -0.2338,  ...,  0.0618,  0.0116,  0.0998]],
#
#                        [[ 0.0892, -0.0469,  0.0037,  ...,  0.1475, -0.0290, -0.2377]],
#
#                        ...,
#
#                        [[ 0.1967,  0.0742,  0.0516,  ...,  0.0360,  0.0682, -0.1328]],
#
#                        [[ 0.1146, -0.0331,  0.0148,  ..., -0.1702, -0.0762, -0.1602]],
#
#                        [[ 0.0081, -0.0875, -0.0769,  ...,  0.0093, -0.0278,  0.1400]]],
#
#
#                       [[[ 0.1158, -0.1649, -0.0106,  ...,  0.1829, -0.0150,  0.1194]],
#
#                        [[-0.1177, -0.2237,  0.0185,  ..., -0.0922,  0.1453, -0.0274]],
#
#                        [[-0.0655,  0.1376,  0.0248,  ..., -0.0735, -0.2106,  0.1005]],
#
#                        ...,
#
#                        [[-0.0621, -0.0152,  0.0368,  ...,  0.0139,  0.0368,  0.0669]],
#
#                        [[ 0.0208,  0.0405,  0.1166,  ...,  0.1593,  0.0328, -0.1515]],
#
#                        [[-0.1399,  0.0863, -0.0239,  ..., -0.0786, -0.0157, -0.0118]]],
#
#
#                       ...,
#
#
#                       [[[ 0.0569,  0.1065, -0.0849,  ..., -0.0636, -0.1377, -0.0393]],
#
#                        [[ 0.0252,  0.0460, -0.1029,  ..., -0.2617, -0.0290, -0.0765]],
#
#                        [[-0.0505,  0.0341,  0.2867,  ..., -0.0943, -0.1792, -0.0431]],
#
#                        ...,
#
#                        [[-0.0466, -0.1417, -0.0007,  ...,  0.0632, -0.0088,  0.0351]],
#
#                        [[ 0.0541,  0.0831,  0.1859,  ..., -0.0938, -0.1093, -0.1064]],
#
#                        [[-0.0947, -0.1131,  0.0429,  ...,  0.0913,  0.0268,  0.0130]]],
#
#
#                       [[[-0.0030, -0.0778,  0.0397,  ...,  0.0505, -0.0472,  0.0070]],
#
#                        [[ 0.0842, -0.1097,  0.0631,  ...,  0.1420,  0.1697, -0.0145]],
#
#                        [[ 0.1645, -0.0477, -0.0055,  ..., -0.1156,  0.1382, -0.0986]],
#
#                        ...,
#
#                        [[-0.0299,  0.1300, -0.0121,  ..., -0.0957, -0.0293,  0.0079]],
#
#                        [[ 0.2179,  0.0614,  0.0252,  ..., -0.0697,  0.0307, -0.0093]],
#
#                        [[ 0.0995, -0.0034,  0.0609,  ..., -0.1937, -0.0284, -0.1979]]],
#
#
#                       [[[-0.0181, -0.1381,  0.0176,  ...,  0.0199,  0.1884, -0.0017]],
#
#                        [[-0.0194,  0.0247,  0.0247,  ..., -0.1018, -0.1908,  0.0391]],
#
#                        [[ 0.1324, -0.1343,  0.1684,  ..., -0.1536,  0.2508, -0.0623]],
#
#                        ...,
#
#                        [[ 0.0131, -0.0864,  0.1743,  ...,  0.1464,  0.0984,  0.1240]],
#
#                        [[-0.0301, -0.0572,  0.0810,  ..., -0.1198,  0.1086, -0.0387]],
#
#                        [[-0.0761, -0.2480,  0.1749,  ..., -0.1474,  0.0743,  0.0902]]]],
#                      device='cuda:0')),
#              ('26.weight',
#               tensor([0.9827, 1.0184, 0.8932, 1.0711, 0.9598, 1.0414, 0.9568, 1.1038, 0.9389,
#                       1.0406, 0.9911, 0.9968, 1.0675, 0.9488, 0.9057, 1.1096, 1.0086, 1.0131],
#                      device='cuda:0')),
#              ('26.bias',
#               tensor([-0.1055,  0.1441,  0.0458,  0.0320,  0.0420, -0.0900, -0.0517,  0.0790,
#                       -0.0961, -0.0332,  0.0594,  0.0089,  0.0222, -0.0194,  0.2042,  0.0045,
#                        0.0622,  0.0612], device='cuda:0')),
#              ('26.running_mean',
#               tensor([0.3001, 0.1832, 0.2246, 0.2564, 0.2823, 0.2907, 0.3991, 0.3256, 0.2344,
#                       0.2223, 0.2043, 0.2734, 0.2121, 0.2623, 0.2220, 0.2602, 0.2463, 0.2699],
#                      device='cuda:0')),
#              ('26.running_var',
#               tensor([0.9375, 0.2123, 0.2985, 0.2256, 0.2709, 0.5566, 0.2660, 0.4567, 0.4172,
#                       0.2448, 0.2074, 0.5741, 0.1708, 0.5692, 0.3326, 0.7613, 0.4654, 0.2096],
#                      device='cuda:0')),
#              ('26.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('27.weight',
#               tensor([[[[ 5.8269e-02,  1.0810e-01, -1.2781e-01, -5.5826e-02, -1.9149e-02]],
#
#                        [[ 3.2222e-02,  2.4430e-02, -1.4771e-01,  8.9433e-02, -1.4644e-02]],
#
#                        [[-3.8634e-02,  1.0819e-02,  7.2916e-02, -1.2420e-01,  3.1554e-02]],
#
#                        ...,
#
#                        [[-2.5189e-03,  2.0869e-05,  1.8509e-01,  3.3430e-02, -1.1391e-01]],
#
#                        [[-1.5408e-02, -1.2462e-01,  1.5455e-01, -7.9833e-02,  1.1548e-02]],
#
#                        [[ 2.0439e-01,  2.4731e-02, -1.0252e-02,  2.3088e-02,  8.2388e-02]]],
#
#
#                       [[[ 1.0258e-01,  3.9452e-02,  8.4583e-02, -5.6680e-02, -5.9745e-02]],
#
#                        [[ 9.3778e-02, -4.6084e-02,  1.1214e-01, -1.9880e-02, -8.7513e-04]],
#
#                        [[ 9.7368e-02,  2.0636e-02, -7.6936e-02,  6.3335e-02,  5.2102e-02]],
#
#                        ...,
#
#                        [[-5.5547e-02,  1.3702e-01,  7.4793e-02, -1.0740e-01, -5.6257e-02]],
#
#                        [[-1.1615e-01,  1.0795e-01,  7.4817e-03,  5.7166e-02, -1.3053e-01]],
#
#                        [[ 3.2516e-02,  5.5054e-03,  1.4968e-02,  2.6467e-02, -1.8786e-02]]],
#
#
#                       [[[ 8.3643e-02,  1.3597e-01, -5.9341e-02, -1.0923e-01, -2.1607e-02]],
#
#                        [[-6.5736e-02,  2.0232e-02, -2.0817e-01, -6.4034e-02,  9.0443e-02]],
#
#                        [[-1.6127e-01,  6.2863e-02,  4.7772e-02, -1.1484e-01,  1.9661e-02]],
#
#                        ...,
#
#                        [[-2.0757e-01, -2.5986e-03, -6.3270e-02,  9.8973e-02, -4.7326e-02]],
#
#                        [[ 2.5090e-01,  9.1713e-02,  1.8736e-01, -1.4585e-02, -8.9822e-02]],
#
#                        [[ 1.1623e-01, -1.1323e-01, -8.1546e-02, -1.2852e-01, -1.7859e-01]]],
#
#
#                       ...,
#
#
#                       [[[ 1.1964e-01,  6.8907e-02,  7.4236e-02, -4.6240e-02, -6.3762e-02]],
#
#                        [[-7.7580e-02, -5.5190e-02,  6.6087e-02,  3.7450e-02,  6.1658e-03]],
#
#                        [[-5.0977e-02, -4.5117e-02, -6.3818e-02,  3.2128e-02, -1.6670e-02]],
#
#                        ...,
#
#                        [[-7.3488e-03,  1.0836e-01, -2.5953e-02, -2.2404e-02, -4.7854e-02]],
#
#                        [[-8.5168e-02, -8.7176e-02,  1.6469e-01,  8.1478e-02, -6.4349e-03]],
#
#                        [[-8.3396e-02, -1.6871e-02,  6.7066e-02, -1.4871e-01,  8.7601e-02]]],
#
#
#                       [[[ 3.5395e-02,  1.4878e-01,  2.0122e-01,  1.4913e-01, -4.8701e-02]],
#
#                        [[-1.3698e-01, -4.7920e-02, -1.7549e-01, -2.4518e-02,  1.3662e-02]],
#
#                        [[-5.0091e-02, -2.2352e-02,  1.3570e-02, -1.2977e-01, -1.0500e-01]],
#
#                        ...,
#
#                        [[-1.0492e-01, -8.6834e-02,  9.1049e-03,  2.4624e-02, -1.1703e-01]],
#
#                        [[ 2.7261e-02, -8.2192e-02, -6.2345e-02, -2.0119e-02, -1.8225e-01]],
#
#                        [[-8.2716e-03, -4.7977e-02, -2.7316e-02, -4.9415e-02, -9.5026e-02]]],
#
#
#                       [[[ 5.5722e-02,  1.0696e-01, -1.5383e-02,  7.5063e-02,  9.0346e-02]],
#
#                        [[-8.9866e-02,  1.6376e-01, -1.9853e-01,  6.2009e-02, -1.2634e-01]],
#
#                        [[ 9.2162e-02,  6.2994e-02,  5.7872e-02,  8.8718e-02, -1.9425e-01]],
#
#                        ...,
#
#                        [[ 1.6020e-01, -9.3450e-02,  1.8587e-01, -1.2127e-02, -3.9382e-02]],
#
#                        [[ 2.1315e-02, -2.6443e-02,  1.0847e-01,  3.2375e-02,  1.3065e-01]],
#
#                        [[ 1.0777e-01,  9.4487e-02,  8.4570e-02,  3.9589e-02,  1.2328e-01]]]],
#                      device='cuda:0')),
#              ('29.weight',
#               tensor([0.9882, 0.9675, 0.9610, 1.0929, 1.0218, 0.8794, 0.9799, 0.9647, 1.0046,
#                       0.9651, 0.9950, 1.1237, 0.9998, 1.0321, 1.0234, 1.0621, 0.9703, 0.9651,
#                       1.0321, 1.0365, 1.0895, 1.0060, 0.9931, 1.0035, 0.9035, 0.9563, 1.0230,
#                       0.8682, 1.0521, 0.9832], device='cuda:0')),
#              ('29.bias',
#               tensor([ 0.0563,  0.1259, -0.0085, -0.0367,  0.0644,  0.0422,  0.0183,  0.1036,
#                        0.0009, -0.0016, -0.0230, -0.0045,  0.0846,  0.1675,  0.0404,  0.1362,
#                        0.0022,  0.0673,  0.1106,  0.0657, -0.0320, -0.0278, -0.0107,  0.0246,
#                       -0.0475,  0.0319,  0.0919,  0.0454, -0.0339,  0.0573], device='cuda:0')),
#              ('29.running_mean',
#               tensor([0.3293, 0.2404, 0.2767, 0.2495, 0.1985, 0.2464, 0.2733, 0.2973, 0.3657,
#                       0.2866, 0.3217, 0.3214, 0.2760, 0.3407, 0.3170, 0.3594, 0.3246, 0.3866,
#                       0.5183, 0.3844, 0.3834, 0.3262, 0.2891, 0.2334, 0.2723, 0.3279, 0.2660,
#                       0.2832, 0.1668, 0.3191], device='cuda:0')),
#              ('29.running_var',
#               tensor([0.7469, 0.8485, 0.2269, 0.9066, 0.3150, 0.4340, 0.1948, 0.7481, 1.6957,
#                       0.6134, 1.3194, 0.4152, 0.2186, 0.4319, 1.2401, 1.6325, 1.2818, 2.1527,
#                       3.0254, 1.8680, 0.8977, 0.7211, 0.8549, 0.4763, 0.5091, 1.0547, 0.1549,
#                       0.5373, 0.1693, 1.8562], device='cuda:0')),
#              ('29.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('30.weight',
#               tensor([[[[ 0.1059,  0.0819,  0.0607,  ...,  0.0448, -0.0629,  0.0640]],
#
#                        [[-0.0046, -0.0096,  0.0772,  ...,  0.0349, -0.1098, -0.0141]],
#
#                        [[ 0.1657, -0.0443,  0.0757,  ...,  0.0166,  0.0655,  0.1315]],
#
#                        ...,
#
#                        [[-0.0560, -0.0291, -0.0021,  ...,  0.0214, -0.0427,  0.0961]],
#
#                        [[-0.0507, -0.0426, -0.0288,  ..., -0.1041,  0.0527, -0.2354]],
#
#                        [[ 0.0457,  0.0732, -0.0194,  ...,  0.0149,  0.0798,  0.0090]]],
#
#
#                       [[[-0.0189, -0.0830,  0.0127,  ..., -0.0976,  0.1185,  0.0554]],
#
#                        [[-0.0193,  0.0015, -0.1018,  ..., -0.0356, -0.0928,  0.0641]],
#
#                        [[-0.0953, -0.1652,  0.0843,  ..., -0.0376,  0.0911, -0.0498]],
#
#                        ...,
#
#                        [[-0.0253,  0.0519, -0.0051,  ...,  0.0225,  0.1054,  0.0605]],
#
#                        [[ 0.0168, -0.0852, -0.0207,  ...,  0.0380, -0.0525, -0.0789]],
#
#                        [[-0.0124,  0.0464,  0.0978,  ...,  0.0393,  0.1180,  0.1169]]],
#
#
#                       [[[ 0.0225,  0.0010, -0.0345,  ...,  0.1477,  0.0652,  0.0391]],
#
#                        [[ 0.1043,  0.0290,  0.0133,  ...,  0.0125,  0.0650,  0.0088]],
#
#                        [[-0.0078, -0.0106,  0.1153,  ..., -0.0082, -0.0961,  0.0025]],
#
#                        ...,
#
#                        [[ 0.1055,  0.0724, -0.0924,  ..., -0.0121, -0.0210, -0.0254]],
#
#                        [[-0.0991,  0.1155, -0.0355,  ...,  0.0833, -0.0176,  0.0079]],
#
#                        [[ 0.0622,  0.0042, -0.0527,  ...,  0.0528,  0.0158,  0.0378]]],
#
#
#                       ...,
#
#
#                       [[[ 0.1442,  0.0167, -0.1473,  ..., -0.0440, -0.0894,  0.0905]],
#
#                        [[-0.0029,  0.0674,  0.0541,  ..., -0.0687, -0.0316, -0.0492]],
#
#                        [[ 0.0617,  0.0567,  0.0011,  ..., -0.0085,  0.0276,  0.0028]],
#
#                        ...,
#
#                        [[ 0.0072,  0.0188,  0.1101,  ..., -0.0281,  0.0510,  0.1007]],
#
#                        [[-0.0104,  0.1263, -0.0263,  ...,  0.0705,  0.0009,  0.0370]],
#
# ...
#
#                        [[-0.0910,  0.0469,  0.0699,  ..., -0.1469, -0.0851, -0.1749]],
#
#                        ...,
#
#                        [[ 0.0292, -0.0701,  0.0716,  ...,  0.1761, -0.1854, -0.1154]],
#
#                        [[-0.0080, -0.0588, -0.0999,  ..., -0.0643,  0.0484, -0.1402]],
#
#                        [[ 0.1012, -0.0404,  0.0185,  ..., -0.0351, -0.0359,  0.1694]]],
#
#
#                       [[[-0.0441, -0.0479, -0.0926,  ...,  0.0118,  0.0902,  0.1610]],
#
#                        [[ 0.1539,  0.0556,  0.0955,  ...,  0.1968,  0.1200,  0.2019]],
#
#                        [[ 0.1112,  0.0006,  0.0920,  ...,  0.1225, -0.0092,  0.0533]],
#
#                        ...,
#
#                        [[ 0.0166, -0.0671,  0.1141,  ...,  0.0635,  0.1164, -0.0309]],
#
#                        [[ 0.1209,  0.0858,  0.1057,  ...,  0.0954,  0.1738,  0.0866]],
#
#                        [[ 0.1703,  0.1258,  0.1058,  ...,  0.1356,  0.1184,  0.1876]]],
#
#
#                       [[[-0.0029,  0.1122, -0.0378,  ..., -0.0980,  0.0508,  0.0018]],
#
#                        [[ 0.0422, -0.1662, -0.1938,  ..., -0.0503, -0.0926,  0.0768]],
#
#                        [[-0.0511, -0.0156, -0.1458,  ...,  0.1103,  0.0066, -0.0345]],
#
#                        ...,
#
#                        [[-0.3387,  0.0546,  0.1685,  ..., -0.0782,  0.0949, -0.0067]],
#
#                        [[ 0.0224,  0.0279, -0.1973,  ...,  0.0355,  0.0923,  0.0898]],
#
#                        [[-0.3033, -0.0850, -0.0234,  ..., -0.0076, -0.0650,  0.1090]]]],
#                      device='cuda:0')),
#              ('46.weight',
#               tensor([0.9629, 0.8389, 0.9764, 1.0547, 1.0365, 0.8843, 0.8858, 0.9397, 0.9635,
#                       1.1044, 1.0752, 1.0389, 0.9876, 1.0301, 0.9571, 0.9471, 1.0301, 0.8041],
#                      device='cuda:0')),
#              ('46.bias',
#               tensor([ 0.1552, -0.0448,  0.1501,  0.1003,  0.1637,  0.1154,  0.0206,  0.1445,
#                        0.0726,  0.1883,  0.1563,  0.1021,  0.1407,  0.0562,  0.1130, -0.0119,
#                        0.1856, -0.1465], device='cuda:0')),
#              ('46.running_mean',
#               tensor([0.3035, 0.1807, 0.3233, 0.1633, 0.3899, 0.2371, 0.2001, 0.2886, 0.2149,
#                       0.2144, 0.3838, 0.1827, 0.1931, 0.1311, 0.1529, 0.2016, 0.5872, 0.2663],
#                      device='cuda:0')),
#              ('46.running_var',
#               tensor([2.6081, 0.0768, 3.7506, 1.4459, 4.2846, 1.7682, 0.4694, 2.1492, 1.3260,
#                       2.0625, 3.7133, 0.7708, 1.1290, 0.3834, 0.7637, 0.2948, 7.9101, 0.1335],
#                      device='cuda:0')),
#              ('46.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('47.weight',
#               tensor([[[[-0.1762, -0.1211,  0.0505,  0.0535,  0.1159]],
#
#                        [[-0.0461,  0.0907,  0.1040,  0.0123, -0.0519]],
#
#                        [[ 0.0043, -0.1006,  0.0541, -0.0064,  0.1022]],
#
#                        ...,
#
#                        [[-0.1202, -0.2359,  0.1523,  0.0712,  0.0583]],
#
#                        [[-0.0284,  0.0580, -0.0871,  0.0594,  0.1049]],
#
#                        [[ 0.0101,  0.1299, -0.0382, -0.1966, -0.1640]]],
#
#
#                       [[[-0.1676, -0.0583,  0.0768,  0.1207,  0.1475]],
#
#                        [[-0.0692,  0.0035,  0.0594,  0.0556, -0.0613]],
#
#                        [[-0.0032, -0.1166, -0.0811,  0.0856, -0.0861]],
#
#                        ...,
#
#                        [[ 0.0054, -0.0349,  0.0365,  0.1262, -0.1348]],
#
#                        [[ 0.0014, -0.1331,  0.1263,  0.1043,  0.1163]],
#
#                        [[-0.0849,  0.1112,  0.1606,  0.0093,  0.0859]]],
#
#
#                       [[[-0.0023,  0.0669, -0.1165,  0.0098, -0.0861]],
#
#                        [[-0.0599,  0.1450,  0.0721, -0.1886, -0.1347]],
#
#                        [[ 0.0828,  0.1000,  0.0259, -0.1102,  0.0005]],
#
#                        ...,
#
#                        [[-0.0953, -0.0791,  0.1123, -0.1549, -0.1453]],
#
#                        [[-0.0041, -0.0768, -0.0201,  0.0603, -0.1342]],
#
#                        [[ 0.0992, -0.0304, -0.0755,  0.1842,  0.0620]]],
#
#
#                       ...,
#
#
#                       [[[-0.0905,  0.0500, -0.1769, -0.0274, -0.1395]],
#
#                        [[ 0.0147,  0.0037,  0.0438, -0.0174,  0.0823]],
#
#                        [[-0.1539, -0.0965,  0.0241, -0.0186, -0.0224]],
#
#                        ...,
#
#                        [[-0.0580,  0.0435,  0.1078, -0.0404,  0.0783]],
#
#                        [[-0.1422, -0.1601, -0.1281, -0.2723, -0.2442]],
#
#                        [[ 0.0939, -0.1383, -0.0041,  0.0881,  0.0822]]],
#
#
#                       [[[ 0.0760,  0.1762,  0.1036, -0.0285, -0.1168]],
#
#                        [[-0.1533,  0.0301, -0.0466, -0.1606, -0.0810]],
#
#                        [[ 0.0330,  0.1484,  0.0709, -0.0221,  0.0396]],
#
#                        ...,
#
#                        [[-0.0603,  0.1027, -0.0539, -0.0588, -0.0432]],
#
#                        [[ 0.0094,  0.0110,  0.0610,  0.1213,  0.0875]],
#
#                        [[ 0.0122, -0.1085, -0.0969, -0.0798, -0.0658]]],
#
#
#                       [[[ 0.1158,  0.0773,  0.0699,  0.0136, -0.0057]],
#
#                        [[-0.0275,  0.0291,  0.1369, -0.0360,  0.0148]],
#
#                        [[ 0.1121, -0.0071, -0.1321,  0.0645,  0.0919]],
#
#                        ...,
#
#                        [[ 0.0040, -0.0389,  0.1113, -0.0932, -0.0211]],
#
#                        [[ 0.0898,  0.0950, -0.0565,  0.0187, -0.0313]],
#
#                        [[ 0.1476,  0.0225,  0.0461, -0.0484, -0.0193]]]], device='cuda:0')),
#              ('49.weight',
#               tensor([1.1018, 0.9377, 1.0058, 1.1054, 0.9818, 1.1706, 0.9248, 0.9239, 0.9913,
#                       1.0210, 0.9274, 1.0156, 1.0504, 0.9640, 1.1472, 1.0986, 0.8478, 0.9073,
#                       0.7893, 0.8345, 0.9859, 0.9846, 1.0573, 0.9675, 0.9809, 0.9933, 1.0715,
#                       1.1192, 0.9465, 0.9994], device='cuda:0')),
#              ('49.bias',
#               tensor([-0.0810,  0.1339, -0.1693, -0.3935, -0.1581, -0.4248, -0.0462,  0.0583,
#                       -0.0598, -0.1044, -0.0836,  0.0572,  0.0023, -0.0585, -0.1173, -0.2297,
#                       -0.1912, -0.0660, -0.0580, -0.0110, -0.0761, -0.1476, -0.1676, -0.0190,
#                       -0.0748,  0.1038, -0.2561, -0.3047,  0.0072, -0.0010], device='cuda:0')),
#              ('49.running_mean',
#               tensor([0.2011, 0.1848, 0.1764, 0.1380, 0.2406, 0.1681, 0.1933, 0.1925, 0.1255,
#                       0.1709, 0.1346, 0.1364, 0.1228, 0.2553, 0.1491, 0.1539, 0.2696, 0.2101,
#                       0.1675, 0.5719, 0.2707, 0.2534, 0.1531, 0.2135, 0.2837, 0.3826, 0.1301,
#                       0.1307, 0.6523, 0.3115], device='cuda:0')),
#              ('49.running_var',
#               tensor([0.9449, 0.9536, 0.2012, 0.0281, 0.0926, 0.0245, 1.8266, 1.9889, 0.0464,
#                       0.0553, 0.2999, 0.0647, 0.9499, 1.2663, 0.0278, 0.2285, 0.5105, 0.5130,
#                       0.2613, 5.4582, 1.9168, 0.1570, 0.4897, 1.3414, 2.1302, 2.7442, 0.0601,
#                       0.0319, 8.6129, 3.0705], device='cuda:0')),
#              ('49.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('50.weight',
#               tensor([[[[-3.6633e-02,  1.7893e-01,  2.0681e-01,  ...,  5.2970e-03,
#                           9.2047e-02,  3.7797e-02]],
#
#                        [[ 9.2145e-03,  1.8621e-01,  1.5179e-01,  ..., -6.8627e-03,
#                           8.3079e-02,  3.9222e-02]],
#
#                        [[ 1.4491e-01, -1.3436e-01,  6.7659e-02,  ..., -3.0626e-02,
#                           1.1743e-01,  2.1082e-02]],
#
#                        ...,
#
#                        [[ 7.1437e-02, -3.1599e-01, -5.5488e-02,  ..., -9.9864e-02,
#                          -6.3835e-03,  8.1109e-02]],
#
#                        [[-2.7344e-02, -1.8960e-01,  3.9919e-02,  ...,  6.1661e-02,
#                           9.3507e-02, -4.2299e-02]],
#
#                        [[-6.3601e-02, -1.1785e-02,  6.8851e-02,  ..., -5.7800e-02,
#                           1.2381e-01,  1.4174e-01]]],
#
#
#                       [[[ 7.1885e-02,  5.0391e-02, -5.5825e-02,  ...,  3.8446e-02,
#                           8.5444e-02,  4.3722e-02]],
#
#                        [[ 2.7901e-02, -2.6794e-02, -7.1982e-02,  ..., -1.3417e-02,
#                          -2.3241e-02,  2.3043e-02]],
#
#                        [[ 4.8288e-02,  7.5874e-02,  5.7120e-02,  ...,  1.4754e-02,
#                          -6.5633e-02,  2.6585e-02]],
#
#                        ...,
#
#                        [[-4.3542e-02,  6.0989e-02, -1.6609e-03,  ...,  4.1048e-02,
#                           1.1677e-01,  8.0413e-02]],
#
#                        [[ 9.5611e-03,  1.1841e-01,  1.3470e-01,  ..., -3.9990e-02,
#                          -1.0763e-01, -4.2907e-02]],
#
#                        [[ 2.8068e-02,  4.6985e-02,  1.4989e-01,  ...,  3.9210e-02,
#                           5.1951e-02,  2.2085e-02]]],
#
#
#                       [[[ 2.8342e-02,  4.5854e-02,  2.1430e-02,  ..., -6.7738e-02,
#                           8.7208e-03, -7.4097e-02]],
#
#                        [[ 8.0041e-02,  5.4663e-02,  4.9119e-02,  ...,  6.6580e-02,
#                           5.3997e-02, -2.5405e-03]],
#
#                        [[ 1.9067e-02, -3.3004e-02,  9.9275e-02,  ...,  1.0874e-02,
#                           1.7772e-02,  4.4356e-02]],
#
#                        ...,
#
#                        [[ 5.8139e-02, -2.3683e-02, -8.3895e-02,  ..., -8.7460e-02,
#                           2.0992e-03, -4.3889e-02]],
#
#                        [[ 4.9184e-02,  7.0101e-02,  4.8290e-02,  ...,  9.4303e-02,
#                           9.3878e-02,  2.5794e-02]],
#
#                        [[ 5.4831e-02,  3.0097e-02,  1.2128e-01,  ...,  1.1530e-02,
#                          -4.4241e-02,  5.4390e-02]]],
#
#
#                       ...,
#
#
#                       [[[ 1.9264e-01,  1.0025e-01, -1.3346e-01,  ...,  8.2200e-02,
#                           1.7277e-02,  6.3769e-02]],
#
#                        [[ 1.7545e-01,  9.8244e-02, -6.3704e-02,  ...,  4.6309e-02,
#                           4.4288e-02, -3.2159e-04]],
#
#                        [[ 3.2255e-02,  8.0691e-02,  1.7340e-02,  ...,  1.9974e-01,
#                          -1.3247e-01,  3.4412e-02]],
#
#                        ...,
#
#                        [[ 1.2674e-01,  1.2430e-01,  3.7742e-02,  ...,  1.0916e-01,
#                           1.6488e-01,  1.0454e-01]],
#
#                        [[-3.0220e-04,  3.4457e-02,  7.1590e-02,  ...,  1.0387e-02,
#                           4.1178e-03,  5.6996e-02]],
#
#                        [[-3.8036e-02,  5.8420e-02,  1.7657e-01,  ...,  4.6494e-02,
#                           8.0515e-02, -5.0889e-02]]],
#
#
#                       [[[-1.4038e-01, -7.5106e-02,  5.6213e-02,  ..., -5.5020e-02,
#                          -3.5373e-02,  5.2932e-02]],
#
#                        [[-2.6813e-03,  2.3205e-02,  2.4469e-01,  ...,  5.6689e-02,
#                           5.3076e-03,  1.8499e-02]],
#
#                        [[-6.1314e-02,  6.5344e-02, -6.4784e-02,  ...,  4.8574e-02,
#                           5.9589e-02,  1.6657e-01]],
#
#                        ...,
#
#                        [[ 3.4327e-02,  9.5190e-03, -2.0110e-01,  ...,  1.0743e-01,
#                           1.2219e-01,  9.0912e-02]],
#
#                        [[ 1.8253e-03, -1.7417e-03, -4.0528e-02,  ...,  1.1060e-01,
#                           9.1951e-02,  9.9551e-02]],
#
#                        [[-8.3892e-02,  1.1091e-02, -9.3424e-02,  ...,  4.8581e-02,
#                           8.3956e-04,  1.2909e-01]]],
#
#
#                       [[[-7.2823e-02, -3.1944e-02,  4.3571e-02,  ...,  3.8688e-02,
#                           8.7964e-02,  5.9492e-02]],
#
#                        [[-4.8612e-03,  2.5727e-02, -3.9446e-03,  ..., -3.4135e-02,
#                          -3.0841e-02, -3.1428e-02]],
#
#                        [[ 1.7763e-02, -5.8829e-02,  1.1400e-01,  ...,  4.4514e-02,
#                           5.2918e-02,  6.1889e-02]],
#
#                        ...,
#
#                        [[ 1.2127e-01,  8.4966e-02,  1.0491e-01,  ..., -4.2909e-02,
#                           8.5595e-02,  5.5087e-02]],
#
#                        [[-4.0301e-02, -4.8435e-02, -2.5537e-02,  ...,  1.2932e-01,
#                           1.8892e-01,  2.8117e-01]],
#
#                        [[-7.7073e-03, -4.0244e-03, -1.0070e-02,  ...,  1.7470e-01,
#                           1.0742e-01,  7.2211e-02]]]], device='cuda:0')),
#              ('52.weight',
#               tensor([0.5029, 0.4752, 0.5958, 0.6267, 0.4726, 0.5507, 0.4965, 0.3892],
#                      device='cuda:0')),
#              ('52.bias',
#               tensor([ 0.0217,  0.0622, -0.0407,  0.1941,  0.0530,  0.0400,  0.0180,  0.0180],
#                      device='cuda:0')),
#              ('52.running_mean',
#               tensor([0.8648, 0.4394, 1.3328, 0.7532, 0.4412, 0.3087, 0.5741, 0.6141],
#                      device='cuda:0')),
#              ('52.running_var',
#               tensor([11.3559, 10.2585, 16.7673,  5.5978, 14.3905, 11.0859,  9.4062,  9.0008],
#                      device='cuda:0')),
#              ('52.num_batches_tracked', tensor(8951, device='cuda:0')),
#              ('55.weight',
#               tensor([[[[-0.0442,  0.0029,  0.0348,  0.0094,  0.0266, -0.0294,  0.0150,
#                          -0.0480,  0.0013]],
#
#                        [[ 0.0258,  0.0735,  0.0704,  0.1280,  0.0320,  0.0168, -0.0508,
#                           0.0217,  0.0181]],
#
#                        [[-0.0369,  0.0285,  0.0211,  0.0160,  0.0211,  0.0222, -0.0008,
#                           0.0217,  0.0209]],
#
#                        [[-0.0178,  0.0511,  0.0005,  0.0060, -0.0022, -0.0008,  0.0064,
#                          -0.0155, -0.0167]],
#
#                        [[ 0.0539,  0.0943, -0.0458,  0.0187,  0.0091,  0.0383,  0.0852,
#                           0.0822,  0.0512]],
#
#                        [[ 0.0730,  0.0335, -0.0115, -0.0343,  0.0090,  0.0274, -0.0440,
#                          -0.0413,  0.0386]],
#
#                        [[ 0.0484,  0.0342,  0.0112,  0.0218, -0.0100, -0.0352,  0.0011,
#                           0.0120,  0.0155]],
#
#                        [[ 0.0192,  0.0213,  0.0359,  0.0321,  0.0310, -0.0343, -0.0321,
#                          -0.0047, -0.0153]]]], device='cuda:0')),
#              ('55.bias', tensor([0.1138], device='cuda:0'))])

# %%
torch.backends.cudnn.enabled
# Out:
# True

# %%
model
# Out:
# Sequential(
#   (0): Lambda()
#   (1): Conv2d(1, 18, kernel_size=(9, 8), stride=(1, 1), padding=(4, 0), bias=False)
#   (2): ReLU()
#   (3): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Conv2d(18, 30, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), bias=False)
#   (5): SaveConnection()
#   (6): ReLU()
#   (7): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(30, 8, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (9): ReLU()
#   (10): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): Conv2d(8, 18, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (12): ReLU()
#   (13): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(18, 30, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), bias=False)
#   (15): SaveConnection()
#   (16): ReLU()
#   (17): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(30, 8, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (19): ReLU()
#   (20): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): Conv2d(8, 18, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (22): ReLU()
#   (23): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): Conv2d(18, 30, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), bias=False)
#   (25): ReLU()
#   (26): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (27): Conv2d(30, 8, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (28): ReLU()
#   (29): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (30): Conv2d(8, 18, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (31): ReLU()
#   (32): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (33): Conv2d(18, 30, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), bias=False)
#   (34): AddConnection()
#   (35): ReLU()
#   (36): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): Conv2d(30, 8, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (38): ReLU()
#   (39): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (40): Conv2d(8, 18, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (41): ReLU()
#   (42): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (43): Conv2d(18, 30, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), bias=False)
#   (44): AddConnection()
#   (45): ReLU()
#   (46): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (47): Conv2d(30, 8, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0), bias=False)
#   (48): ReLU()
#   (49): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (50): Dropout(p=0.2, inplace=False)
#   (51): Conv2d(8, 1, kernel_size=(1, 1), stride=(1, 1))
# )
